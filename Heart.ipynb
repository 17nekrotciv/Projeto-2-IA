# %% [markdown]
# # Arvore de Decisao

# %%
#Importa as bibliotecas Pandas e Numpy
import pandas as pd
import numpy as np

# %%
# na_values = substitui o valor '?' (dado faltante) para Nan
dataset = pd.read_csv('heart.dat', sep=' ',na_values='?',names=['Age','Sex','Chest pain type','Resting blood pressure','Serum cholesterol in mg/dl','Fasting blood sugar ','Resting electrocardiographic results','Maximum heart rate achieved','Exercise induced angina','Oldpeak','The slope of the peak','Number of major vessels','num'])
dataset
# Out:
#       Age  Sex  Chest pain type  Resting blood pressure  \
# 70.0  1.0  4.0            130.0                   322.0
# 67.0  0.0  3.0            115.0                   564.0
# 57.0  1.0  2.0            124.0                   261.0
# 64.0  1.0  4.0            128.0                   263.0
# 74.0  0.0  2.0            120.0                   269.0
# ...   ...  ...              ...                     ...
# 52.0  1.0  3.0            172.0                   199.0
# 44.0  1.0  2.0            120.0                   263.0
# 56.0  0.0  2.0            140.0                   294.0
# 57.0  1.0  4.0            140.0                   192.0
# 67.0  1.0  4.0            160.0                   286.0
#
#       Serum cholesterol in mg/dl  Fasting blood sugar   \
# 70.0                         0.0                   2.0
# 67.0                         0.0                   2.0
# 57.0                         0.0                   0.0
# 64.0                         0.0                   0.0
# 74.0                         0.0                   2.0
# ...                          ...                   ...
# 52.0                         1.0                   0.0
# 44.0                         0.0                   0.0
# 56.0                         0.0                   2.0
# 57.0                         0.0                   0.0
# 67.0                         0.0                   2.0
#
#       Resting electrocardiographic results  Maximum heart rate achieved  \
# 70.0                                 109.0                          0.0
# 67.0                                 160.0                          0.0
# 57.0                                 141.0                          0.0
# 64.0                                 105.0                          1.0
# 74.0                                 121.0                          1.0
# ...                                    ...                          ...
# 52.0                                 162.0                          0.0
# 44.0                                 173.0                          0.0
# 56.0                                 153.0                          0.0
# 57.0                                 148.0                          0.0
# 67.0                                 108.0                          1.0
#
#       Exercise induced angina  Oldpeak  The slope of the peak  \
# 70.0                      2.4      2.0                    3.0
# 67.0                      1.6      2.0                    0.0
# 57.0                      0.3      1.0                    0.0
# 64.0                      0.2      2.0                    1.0
# 74.0                      0.2      1.0                    1.0
# ...                       ...      ...                    ...
# 52.0                      0.5      1.0                    0.0
# 44.0                      0.0      1.0                    0.0
# 56.0                      1.3      2.0                    0.0
# 57.0                      0.4      2.0                    0.0
# 67.0                      1.5      2.0                    3.0
#
#       Number of major vessels  num
# 70.0                      3.0    2
# 67.0                      7.0    1
# 57.0                      7.0    2
# 64.0                      7.0    1
# 74.0                      3.0    1
# ...                       ...  ...
# 52.0                      7.0    1
# 44.0                      7.0    1
# 56.0                      3.0    1
# 57.0                      6.0    1
# 67.0                      3.0    2
#
# [270 rows x 13 columns]

# %%
# elimina as linhas com dados faltantes
dataset = dataset.dropna(axis=0)
dataset
# Out:
#       Age  Sex  Chest pain type  Resting blood pressure  \
# 70.0  1.0  4.0            130.0                   322.0
# 67.0  0.0  3.0            115.0                   564.0
# 57.0  1.0  2.0            124.0                   261.0
# 64.0  1.0  4.0            128.0                   263.0
# 74.0  0.0  2.0            120.0                   269.0
# ...   ...  ...              ...                     ...
# 52.0  1.0  3.0            172.0                   199.0
# 44.0  1.0  2.0            120.0                   263.0
# 56.0  0.0  2.0            140.0                   294.0
# 57.0  1.0  4.0            140.0                   192.0
# 67.0  1.0  4.0            160.0                   286.0
#
#       Serum cholesterol in mg/dl  Fasting blood sugar   \
# 70.0                         0.0                   2.0
# 67.0                         0.0                   2.0
# 57.0                         0.0                   0.0
# 64.0                         0.0                   0.0
# 74.0                         0.0                   2.0
# ...                          ...                   ...
# 52.0                         1.0                   0.0
# 44.0                         0.0                   0.0
# 56.0                         0.0                   2.0
# 57.0                         0.0                   0.0
# 67.0                         0.0                   2.0
#
#       Resting electrocardiographic results  Maximum heart rate achieved  \
# 70.0                                 109.0                          0.0
# 67.0                                 160.0                          0.0
# 57.0                                 141.0                          0.0
# 64.0                                 105.0                          1.0
# 74.0                                 121.0                          1.0
# ...                                    ...                          ...
# 52.0                                 162.0                          0.0
# 44.0                                 173.0                          0.0
# 56.0                                 153.0                          0.0
# 57.0                                 148.0                          0.0
# 67.0                                 108.0                          1.0
#
#       Exercise induced angina  Oldpeak  The slope of the peak  \
# 70.0                      2.4      2.0                    3.0
# 67.0                      1.6      2.0                    0.0
# 57.0                      0.3      1.0                    0.0
# 64.0                      0.2      2.0                    1.0
# 74.0                      0.2      1.0                    1.0
# ...                       ...      ...                    ...
# 52.0                      0.5      1.0                    0.0
# 44.0                      0.0      1.0                    0.0
# 56.0                      1.3      2.0                    0.0
# 57.0                      0.4      2.0                    0.0
# 67.0                      1.5      2.0                    3.0
#
#       Number of major vessels  num
# 70.0                      3.0    2
# 67.0                      7.0    1
# 57.0                      7.0    2
# 64.0                      7.0    1
# 74.0                      3.0    1
# ...                       ...  ...
# 52.0                      7.0    1
# 44.0                      7.0    1
# 56.0                      3.0    1
# 57.0                      6.0    1
# 67.0                      3.0    2
#
# [270 rows x 13 columns]

# %%
#Separando as variáveis independentes (conjunto X) e a variável dependente y (que neste caso é a coluna 'num')
X = dataset.loc[:, dataset.columns != 'num'] 
y = np.array(dataset.loc[:, dataset.columns == 'num']).ravel()

# %%
#Define os parametros do metodo de Arvore de Decisao
parameters= {'criterion':['gini'],'max_depth':[4,5,6,7,8,9,10,11,12,15,20,30,40,50,70,90,120,150], 'random_state': [56]}

# %%
# importa o método do sklearn que separa em conjunto de treino e teste
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.26, stratify=y, random_state=56)

# %%
# importa o GridSearchCV
from sklearn.model_selection import GridSearchCV
# importa a arvore de decisão
from sklearn.tree import DecisionTreeClassifier
# instancia o classificador 
clf = DecisionTreeClassifier()
gs_tree = GridSearchCV(clf,parameters, cv = 10, scoring = 'accuracy')
# o grid search treinará todos os modelos conforme a parametrização acima
gs_tree.fit(X,y)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini'],
#                          'max_depth': [4, 5, 6, 7, 8, 9, 10, 11, 12, 15, 20, 30,
#                                        40, 50, 70, 90, 120, 150],
#                          'random_state': [56]},
#              scoring='accuracy')

# %%
# coloca os resultados num Frame para melhor visulização
results = pd.DataFrame(gs_tree.cv_results_)
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.003011      0.000935         0.001579        0.000265
# 1        0.002689      0.000448         0.001469        0.000240
# 2        0.002911      0.000741         0.001520        0.000355
# 3        0.002651      0.000082         0.001516        0.000230
# 4        0.003540      0.002385         0.001801        0.000810
# 5        0.003091      0.000627         0.001599        0.000372
# 6        0.002853      0.000213         0.001471        0.000058
# 7        0.003201      0.000599         0.001689        0.000251
# 8        0.002851      0.000146         0.001484        0.000064
# 9        0.002906      0.000562         0.001454        0.000095
# 10       0.002720      0.000087         0.001428        0.000053
# 11       0.002856      0.000272         0.001487        0.000108
# 12       0.002675      0.000071         0.001415        0.000037
# 13       0.003140      0.000739         0.001822        0.000533
# 14       0.002699      0.000051         0.001497        0.000084
# 15       0.002637      0.000041         0.001416        0.000070
# 16       0.002632      0.000124         0.001374        0.000021
# 17       0.002705      0.000174         0.001492        0.000195
#
#    param_criterion param_max_depth param_random_state  \
# 0             gini               4                 56
# 1             gini               5                 56
# 2             gini               6                 56
# 3             gini               7                 56
# 4             gini               8                 56
# 5             gini               9                 56
# 6             gini              10                 56
# 7             gini              11                 56
# 8             gini              12                 56
# 9             gini              15                 56
# 10            gini              20                 56
# 11            gini              30                 56
# 12            gini              40                 56
# 13            gini              50                 56
# 14            gini              70                 56
# 15            gini              90                 56
# 16            gini             120                 56
# 17            gini             150                 56
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_depth': 4, 'random_...           0.703704
# 1   {'criterion': 'gini', 'max_depth': 5, 'random_...           0.592593
# 2   {'criterion': 'gini', 'max_depth': 6, 'random_...           0.703704
# 3   {'criterion': 'gini', 'max_depth': 7, 'random_...           0.666667
# 4   {'criterion': 'gini', 'max_depth': 8, 'random_...           0.592593
# 5   {'criterion': 'gini', 'max_depth': 9, 'random_...           0.629630
# 6   {'criterion': 'gini', 'max_depth': 10, 'random...           0.629630
# 7   {'criterion': 'gini', 'max_depth': 11, 'random...           0.629630
# 8   {'criterion': 'gini', 'max_depth': 12, 'random...           0.629630
# 9   {'criterion': 'gini', 'max_depth': 15, 'random...           0.629630
# 10  {'criterion': 'gini', 'max_depth': 20, 'random...           0.629630
# 11  {'criterion': 'gini', 'max_depth': 30, 'random...           0.629630
# 12  {'criterion': 'gini', 'max_depth': 40, 'random...           0.629630
# 13  {'criterion': 'gini', 'max_depth': 50, 'random...           0.629630
# 14  {'criterion': 'gini', 'max_depth': 70, 'random...           0.629630
# 15  {'criterion': 'gini', 'max_depth': 90, 'random...           0.629630
# 16  {'criterion': 'gini', 'max_depth': 120, 'rando...           0.629630
# 17  {'criterion': 'gini', 'max_depth': 150, 'rando...           0.629630
#
#     split1_test_score  ...  split3_test_score  split4_test_score  \
# 0            0.740741  ...           0.814815           0.851852
# 1            0.777778  ...           0.777778           0.888889
# 2            0.703704  ...           0.777778           0.888889
# 3            0.740741  ...           0.740741           0.777778
# 4            0.777778  ...           0.740741           0.703704
# 5            0.777778  ...           0.740741           0.777778
# 6            0.777778  ...           0.740741           0.777778
# 7            0.777778  ...           0.740741           0.814815
# 8            0.777778  ...           0.740741           0.814815
# 9            0.777778  ...           0.740741           0.814815
# 10           0.777778  ...           0.740741           0.814815
# 11           0.777778  ...           0.740741           0.814815
# 12           0.777778  ...           0.740741           0.814815
# 13           0.777778  ...           0.740741           0.814815
# 14           0.777778  ...           0.740741           0.814815
# 15           0.777778  ...           0.740741           0.814815
# 16           0.777778  ...           0.740741           0.814815
# 17           0.777778  ...           0.740741           0.814815
#
#     split5_test_score  split6_test_score  split7_test_score  \
# 0            0.629630           0.629630           0.740741
# 1            0.592593           0.740741           0.703704
# 2            0.629630           0.666667           0.703704
# 3            0.703704           0.592593           0.666667
# 4            0.666667           0.592593           0.777778
# 5            0.666667           0.629630           0.666667
# 6            0.666667           0.592593           0.666667
# 7            0.666667           0.555556           0.666667
# 8            0.666667           0.555556           0.666667
# 9            0.666667           0.555556           0.666667
# 10           0.666667           0.555556           0.666667
# 11           0.666667           0.555556           0.666667
# 12           0.666667           0.555556           0.666667
# 13           0.666667           0.555556           0.666667
# 14           0.666667           0.555556           0.666667
# 15           0.666667           0.555556           0.666667
# 16           0.666667           0.555556           0.666667
# 17           0.666667           0.555556           0.666667
#
#     split8_test_score  split9_test_score  mean_test_score  std_test_score  \
# 0            0.814815           0.777778         0.744444        0.071146
# 1            0.777778           0.740741         0.737037        0.085185
# 2            0.814815           0.740741         0.744444        0.074903
# 3            0.740741           0.777778         0.714815        0.055060
# 4            0.703704           0.740741         0.711111        0.071817
# 5            0.629630           0.740741         0.707407        0.067179
# 6            0.629630           0.740741         0.703704        0.072198
# 7            0.629630           0.740741         0.703704        0.082817
# 8            0.629630           0.740741         0.703704        0.082817
# 9            0.629630           0.740741         0.703704        0.082817
# 10           0.629630           0.740741         0.703704        0.082817
# 11           0.629630           0.740741         0.703704        0.082817
# 12           0.629630           0.740741         0.703704        0.082817
# 13           0.629630           0.740741         0.703704        0.082817
# 14           0.629630           0.740741         0.703704        0.082817
# 15           0.629630           0.740741         0.703704        0.082817
# 16           0.629630           0.740741         0.703704        0.082817
# 17           0.629630           0.740741         0.703704        0.082817
#
#     rank_test_score
# 0                 2
# 1                 3
# 2                 1
# 3                 4
# 4                 5
# 5                 6
# 6                 7
# 7                 7
# 8                 7
# 9                 7
# 10                7
# 11                7
# 12                7
# 13                7
# 14                7
# 15                7
# 16                7
# 17                7
#
# [18 rows x 21 columns]

# %%
#criar uma visão para facilitar a visualização dos resultados, e ordenar os resultados conforme os resultados.
view = ['params', 'mean_test_score', 'std_test_score', 'rank_test_score']
results[view].sort_values(by='rank_test_score')
# Out:
#                                                params  mean_test_score  \
# 2   {'criterion': 'gini', 'max_depth': 6, 'random_...         0.744444
# 0   {'criterion': 'gini', 'max_depth': 4, 'random_...         0.744444
# 1   {'criterion': 'gini', 'max_depth': 5, 'random_...         0.737037
# 3   {'criterion': 'gini', 'max_depth': 7, 'random_...         0.714815
# 4   {'criterion': 'gini', 'max_depth': 8, 'random_...         0.711111
# 5   {'criterion': 'gini', 'max_depth': 9, 'random_...         0.707407
# 15  {'criterion': 'gini', 'max_depth': 90, 'random...         0.703704
# 14  {'criterion': 'gini', 'max_depth': 70, 'random...         0.703704
# 13  {'criterion': 'gini', 'max_depth': 50, 'random...         0.703704
# 12  {'criterion': 'gini', 'max_depth': 40, 'random...         0.703704
# 11  {'criterion': 'gini', 'max_depth': 30, 'random...         0.703704
# 8   {'criterion': 'gini', 'max_depth': 12, 'random...         0.703704
# 9   {'criterion': 'gini', 'max_depth': 15, 'random...         0.703704
# 16  {'criterion': 'gini', 'max_depth': 120, 'rando...         0.703704
# 7   {'criterion': 'gini', 'max_depth': 11, 'random...         0.703704
# 6   {'criterion': 'gini', 'max_depth': 10, 'random...         0.703704
# 10  {'criterion': 'gini', 'max_depth': 20, 'random...         0.703704
# 17  {'criterion': 'gini', 'max_depth': 150, 'rando...         0.703704
#
#     std_test_score  rank_test_score
# 2         0.074903                1
# 0         0.071146                2
# 1         0.085185                3
# 3         0.055060                4
# 4         0.071817                5
# 5         0.067179                6
# 15        0.082817                7
# 14        0.082817                7
# 13        0.082817                7
# 12        0.082817                7
# 11        0.082817                7
# 8         0.082817                7
# 9         0.082817                7
# 16        0.082817                7
# 7         0.082817                7
# 6         0.072198                7
# 10        0.082817                7
# 17        0.082817                7

# %% [markdown]
# # Multilayer-Perceptron (redes neurais)

# %%
#Importa as bibliotecas Pandas e Numpy
import pandas as pd
import numpy as np

# %%
# na_values = substitui o valor '?' (dado faltante) para Nan
dataset = pd.read_csv('heart.dat', sep=' ', na_values='?',names=['Age','Sex','Chest pain type','Resting blood pressure','Serum cholesterol in mg/dl','Fasting blood sugar ','Resting electrocardiographic results','Maximum heart rate achieved','Exercise induced angina','Oldpeak','The slope of the peak','Number of major vessels','num'])

dataset
# Out:
#       Age  Sex  Chest pain type  Resting blood pressure  \
# 70.0  1.0  4.0            130.0                   322.0
# 67.0  0.0  3.0            115.0                   564.0
# 57.0  1.0  2.0            124.0                   261.0
# 64.0  1.0  4.0            128.0                   263.0
# 74.0  0.0  2.0            120.0                   269.0
# ...   ...  ...              ...                     ...
# 52.0  1.0  3.0            172.0                   199.0
# 44.0  1.0  2.0            120.0                   263.0
# 56.0  0.0  2.0            140.0                   294.0
# 57.0  1.0  4.0            140.0                   192.0
# 67.0  1.0  4.0            160.0                   286.0
#
#       Serum cholesterol in mg/dl  Fasting blood sugar   \
# 70.0                         0.0                   2.0
# 67.0                         0.0                   2.0
# 57.0                         0.0                   0.0
# 64.0                         0.0                   0.0
# 74.0                         0.0                   2.0
# ...                          ...                   ...
# 52.0                         1.0                   0.0
# 44.0                         0.0                   0.0
# 56.0                         0.0                   2.0
# 57.0                         0.0                   0.0
# 67.0                         0.0                   2.0
#
#       Resting electrocardiographic results  Maximum heart rate achieved  \
# 70.0                                 109.0                          0.0
# 67.0                                 160.0                          0.0
# 57.0                                 141.0                          0.0
# 64.0                                 105.0                          1.0
# 74.0                                 121.0                          1.0
# ...                                    ...                          ...
# 52.0                                 162.0                          0.0
# 44.0                                 173.0                          0.0
# 56.0                                 153.0                          0.0
# 57.0                                 148.0                          0.0
# 67.0                                 108.0                          1.0
#
#       Exercise induced angina  Oldpeak  The slope of the peak  \
# 70.0                      2.4      2.0                    3.0
# 67.0                      1.6      2.0                    0.0
# 57.0                      0.3      1.0                    0.0
# 64.0                      0.2      2.0                    1.0
# 74.0                      0.2      1.0                    1.0
# ...                       ...      ...                    ...
# 52.0                      0.5      1.0                    0.0
# 44.0                      0.0      1.0                    0.0
# 56.0                      1.3      2.0                    0.0
# 57.0                      0.4      2.0                    0.0
# 67.0                      1.5      2.0                    3.0
#
#       Number of major vessels  num
# 70.0                      3.0    2
# 67.0                      7.0    1
# 57.0                      7.0    2
# 64.0                      7.0    1
# 74.0                      3.0    1
# ...                       ...  ...
# 52.0                      7.0    1
# 44.0                      7.0    1
# 56.0                      3.0    1
# 57.0                      6.0    1
# 67.0                      3.0    2
#
# [270 rows x 13 columns]

# %%
# elimina as linhas com dados faltantes
dataset = dataset.dropna(axis=0)
dataset
# Out:
#       Age  Sex  Chest pain type  Resting blood pressure  \
# 70.0  1.0  4.0            130.0                   322.0
# 67.0  0.0  3.0            115.0                   564.0
# 57.0  1.0  2.0            124.0                   261.0
# 64.0  1.0  4.0            128.0                   263.0
# 74.0  0.0  2.0            120.0                   269.0
# ...   ...  ...              ...                     ...
# 52.0  1.0  3.0            172.0                   199.0
# 44.0  1.0  2.0            120.0                   263.0
# 56.0  0.0  2.0            140.0                   294.0
# 57.0  1.0  4.0            140.0                   192.0
# 67.0  1.0  4.0            160.0                   286.0
#
#       Serum cholesterol in mg/dl  Fasting blood sugar   \
# 70.0                         0.0                   2.0
# 67.0                         0.0                   2.0
# 57.0                         0.0                   0.0
# 64.0                         0.0                   0.0
# 74.0                         0.0                   2.0
# ...                          ...                   ...
# 52.0                         1.0                   0.0
# 44.0                         0.0                   0.0
# 56.0                         0.0                   2.0
# 57.0                         0.0                   0.0
# 67.0                         0.0                   2.0
#
#       Resting electrocardiographic results  Maximum heart rate achieved  \
# 70.0                                 109.0                          0.0
# 67.0                                 160.0                          0.0
# 57.0                                 141.0                          0.0
# 64.0                                 105.0                          1.0
# 74.0                                 121.0                          1.0
# ...                                    ...                          ...
# 52.0                                 162.0                          0.0
# 44.0                                 173.0                          0.0
# 56.0                                 153.0                          0.0
# 57.0                                 148.0                          0.0
# 67.0                                 108.0                          1.0
#
#       Exercise induced angina  Oldpeak  The slope of the peak  \
# 70.0                      2.4      2.0                    3.0
# 67.0                      1.6      2.0                    0.0
# 57.0                      0.3      1.0                    0.0
# 64.0                      0.2      2.0                    1.0
# 74.0                      0.2      1.0                    1.0
# ...                       ...      ...                    ...
# 52.0                      0.5      1.0                    0.0
# 44.0                      0.0      1.0                    0.0
# 56.0                      1.3      2.0                    0.0
# 57.0                      0.4      2.0                    0.0
# 67.0                      1.5      2.0                    3.0
#
#       Number of major vessels  num
# 70.0                      3.0    2
# 67.0                      7.0    1
# 57.0                      7.0    2
# 64.0                      7.0    1
# 74.0                      3.0    1
# ...                       ...  ...
# 52.0                      7.0    1
# 44.0                      7.0    1
# 56.0                      3.0    1
# 57.0                      6.0    1
# 67.0                      3.0    2
#
# [270 rows x 13 columns]

# %%
#Separando as variáveis independentes (conjunto X) e a variável dependente y (que neste caso é a coluna 'num')
X = dataset.loc[:, dataset.columns != 'num'] 
y = np.array(dataset.loc[:, dataset.columns == 'num']).ravel()

# %%
# importa o algoritmo de classificação Multilayer-Perceptron (redes neurais)
from sklearn.neural_network import MLPClassifier
# importa o GridSearchCV
from sklearn.model_selection import GridSearchCV

# na MLP um parâmetro a ser testado é a quantidade de neurônios na camada escondida, 
# onde utilzamos uma tupla para representar a camada escondida.
# Por exemplo:
# (5) - Cinco neurônios e uma camada escondida
# (8, 5) - Oito neurônios na primeira camada escondida e cinco neurônios na segunda camada escondida.
# Interessante nesse projeto utilizar no máximo duas camadas para verificação 
# Quanto mais camadas e neurônios maior o tempo de processamento do algoritmo
parameters = {'hidden_layer_sizes' : [(5), (8), (15), (5, 3), (8, 5), (10, 5)],
              'max_iter' : [3000], 'random_state' : [56]}

# define o algoritmo de classificação que será usado
mlp = MLPClassifier()
gs_mlp = GridSearchCV(mlp, parameters, cv=10, scoring='accuracy')
# o grid search treinará todos os modelos conforme a parametrização acima
gs_mlp.fit(X, y)
# Out:
# GridSearchCV(cv=10, estimator=MLPClassifier(),
#              param_grid={'hidden_layer_sizes': [5, 8, 15, (5, 3), (8, 5),
#                                                 (10, 5)],
#                          'max_iter': [3000], 'random_state': [56]},
#              scoring='accuracy')

# %%
#criar uma visão para facilitar a visualização dos resultados, e ordenar os resultados conforme os resultados.
view = ['params', 'mean_test_score', 'std_test_score', 'rank_test_score']
results = pd.DataFrame(gs_mlp.cv_results_)
results[view].sort_values(by='rank_test_score')
# Out:
#                                               params  mean_test_score  \
# 2  {'hidden_layer_sizes': 15, 'max_iter': 3000, '...         0.829630
# 3  {'hidden_layer_sizes': (5, 3), 'max_iter': 300...         0.818519
# 5  {'hidden_layer_sizes': (10, 5), 'max_iter': 30...         0.814815
# 4  {'hidden_layer_sizes': (8, 5), 'max_iter': 300...         0.770370
# 1  {'hidden_layer_sizes': 8, 'max_iter': 3000, 'r...         0.555556
# 0  {'hidden_layer_sizes': 5, 'max_iter': 3000, 'r...         0.444444
#
#    std_test_score  rank_test_score
# 2    4.444444e-02                1
# 3    4.520947e-02                2
# 5    8.114408e-02                3
# 4    7.370277e-02                4
# 1    0.000000e+00                5
# 0    5.551115e-17                6

# %% [markdown]
# # Naive Bayes

# %%
#Importa as bibliotecas Pandas e Numpy
import pandas as pd
import numpy as np

# %%
# na_values = substitui o valor '?' (dado faltante) para Nan
dataset = pd.read_csv('heart.dat', sep=' ', na_values='?',names=['Age','Sex','Chest pain type','Resting blood pressure','Serum cholesterol in mg/dl','Fasting blood sugar ','Resting electrocardiographic results','Maximum heart rate achieved','Exercise induced angina','Oldpeak','The slope of the peak','Number of major vessels','num'])

dataset
# Out:
#       Age  Sex  Chest pain type  Resting blood pressure  \
# 70.0  1.0  4.0            130.0                   322.0
# 67.0  0.0  3.0            115.0                   564.0
# 57.0  1.0  2.0            124.0                   261.0
# 64.0  1.0  4.0            128.0                   263.0
# 74.0  0.0  2.0            120.0                   269.0
# ...   ...  ...              ...                     ...
# 52.0  1.0  3.0            172.0                   199.0
# 44.0  1.0  2.0            120.0                   263.0
# 56.0  0.0  2.0            140.0                   294.0
# 57.0  1.0  4.0            140.0                   192.0
# 67.0  1.0  4.0            160.0                   286.0
#
#       Serum cholesterol in mg/dl  Fasting blood sugar   \
# 70.0                         0.0                   2.0
# 67.0                         0.0                   2.0
# 57.0                         0.0                   0.0
# 64.0                         0.0                   0.0
# 74.0                         0.0                   2.0
# ...                          ...                   ...
# 52.0                         1.0                   0.0
# 44.0                         0.0                   0.0
# 56.0                         0.0                   2.0
# 57.0                         0.0                   0.0
# 67.0                         0.0                   2.0
#
#       Resting electrocardiographic results  Maximum heart rate achieved  \
# 70.0                                 109.0                          0.0
# 67.0                                 160.0                          0.0
# 57.0                                 141.0                          0.0
# 64.0                                 105.0                          1.0
# 74.0                                 121.0                          1.0
# ...                                    ...                          ...
# 52.0                                 162.0                          0.0
# 44.0                                 173.0                          0.0
# 56.0                                 153.0                          0.0
# 57.0                                 148.0                          0.0
# 67.0                                 108.0                          1.0
#
#       Exercise induced angina  Oldpeak  The slope of the peak  \
# 70.0                      2.4      2.0                    3.0
# 67.0                      1.6      2.0                    0.0
# 57.0                      0.3      1.0                    0.0
# 64.0                      0.2      2.0                    1.0
# 74.0                      0.2      1.0                    1.0
# ...                       ...      ...                    ...
# 52.0                      0.5      1.0                    0.0
# 44.0                      0.0      1.0                    0.0
# 56.0                      1.3      2.0                    0.0
# 57.0                      0.4      2.0                    0.0
# 67.0                      1.5      2.0                    3.0
#
#       Number of major vessels  num
# 70.0                      3.0    2
# 67.0                      7.0    1
# 57.0                      7.0    2
# 64.0                      7.0    1
# 74.0                      3.0    1
# ...                       ...  ...
# 52.0                      7.0    1
# 44.0                      7.0    1
# 56.0                      3.0    1
# 57.0                      6.0    1
# 67.0                      3.0    2
#
# [270 rows x 13 columns]

# %%
# elimina as linhas com dados faltantes
dataset = dataset.dropna(axis=0)
dataset
# Out:
#       Age  Sex  Chest pain type  Resting blood pressure  \
# 70.0  1.0  4.0            130.0                   322.0
# 67.0  0.0  3.0            115.0                   564.0
# 57.0  1.0  2.0            124.0                   261.0
# 64.0  1.0  4.0            128.0                   263.0
# 74.0  0.0  2.0            120.0                   269.0
# ...   ...  ...              ...                     ...
# 52.0  1.0  3.0            172.0                   199.0
# 44.0  1.0  2.0            120.0                   263.0
# 56.0  0.0  2.0            140.0                   294.0
# 57.0  1.0  4.0            140.0                   192.0
# 67.0  1.0  4.0            160.0                   286.0
#
#       Serum cholesterol in mg/dl  Fasting blood sugar   \
# 70.0                         0.0                   2.0
# 67.0                         0.0                   2.0
# 57.0                         0.0                   0.0
# 64.0                         0.0                   0.0
# 74.0                         0.0                   2.0
# ...                          ...                   ...
# 52.0                         1.0                   0.0
# 44.0                         0.0                   0.0
# 56.0                         0.0                   2.0
# 57.0                         0.0                   0.0
# 67.0                         0.0                   2.0
#
#       Resting electrocardiographic results  Maximum heart rate achieved  \
# 70.0                                 109.0                          0.0
# 67.0                                 160.0                          0.0
# 57.0                                 141.0                          0.0
# 64.0                                 105.0                          1.0
# 74.0                                 121.0                          1.0
# ...                                    ...                          ...
# 52.0                                 162.0                          0.0
# 44.0                                 173.0                          0.0
# 56.0                                 153.0                          0.0
# 57.0                                 148.0                          0.0
# 67.0                                 108.0                          1.0
#
#       Exercise induced angina  Oldpeak  The slope of the peak  \
# 70.0                      2.4      2.0                    3.0
# 67.0                      1.6      2.0                    0.0
# 57.0                      0.3      1.0                    0.0
# 64.0                      0.2      2.0                    1.0
# 74.0                      0.2      1.0                    1.0
# ...                       ...      ...                    ...
# 52.0                      0.5      1.0                    0.0
# 44.0                      0.0      1.0                    0.0
# 56.0                      1.3      2.0                    0.0
# 57.0                      0.4      2.0                    0.0
# 67.0                      1.5      2.0                    3.0
#
#       Number of major vessels  num
# 70.0                      3.0    2
# 67.0                      7.0    1
# 57.0                      7.0    2
# 64.0                      7.0    1
# 74.0                      3.0    1
# ...                       ...  ...
# 52.0                      7.0    1
# 44.0                      7.0    1
# 56.0                      3.0    1
# 57.0                      6.0    1
# 67.0                      3.0    2
#
# [270 rows x 13 columns]

# %%
#Separando as variáveis independentes (conjunto X) e a variável dependente y (que neste caso é a coluna 'num')
X = dataset.loc[:, dataset.columns != 'num'] 
y = np.array(dataset.loc[:, dataset.columns == 'num']).ravel()

# %%
#Define os parametros do metodo Naive Bayes
param = {'var_smoothing': np.logspace(0,-9, num=100)}

# %%
# importa o método do sklearn que separa em conjunto de treino e teste
from sklearn.model_selection import train_test_split
# importa o algoritmo Naive Bayes 
from sklearn.naive_bayes import GaussianNB
# importa o GridSearchCV
from sklearn.model_selection import GridSearchCV

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.45, random_state=56)
# instancia o classificador
gnb = GaussianNB()
gs_NB = GridSearchCV(gnb, param, cv = 10, scoring = 'accuracy')
# o grid search treinará todos os modelos conforme a parametrização acima
gs_NB.fit(X,y)
# Out:
# GridSearchCV(cv=10, estimator=GaussianNB(),
#              param_grid={'var_smoothing': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#        4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#        1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#        8.11130831e-02, 6.57933225e-02, 5.33669923e-02, 4.32876128e-02,
#        3.51119173e-02, 2.84803587e-02, 2.3...
#        1.23284674e-07, 1.00000000e-07, 8.11130831e-08, 6.57933225e-08,
#        5.33669923e-08, 4.32876128e-08, 3.51119173e-08, 2.84803587e-08,
#        2.31012970e-08, 1.87381742e-08, 1.51991108e-08, 1.23284674e-08,
#        1.00000000e-08, 8.11130831e-09, 6.57933225e-09, 5.33669923e-09,
#        4.32876128e-09, 3.51119173e-09, 2.84803587e-09, 2.31012970e-09,
#        1.87381742e-09, 1.51991108e-09, 1.23284674e-09, 1.00000000e-09])},
#              scoring='accuracy')

# %%
#criar uma visão para facilitar a visualização dos resultados, e ordenar os resultados conforme os resultados.
view = ['params', 'mean_test_score', 'std_test_score', 'rank_test_score']
results = pd.DataFrame(gs_NB.cv_results_)
results[view].sort_values(by='rank_test_score')
# Out:
#                                        params  mean_test_score  \
# 49   {'var_smoothing': 3.511191734215127e-05}         0.859259
# 74   {'var_smoothing': 1.873817422860383e-07}         0.859259
# 73   {'var_smoothing': 2.310129700083158e-07}         0.859259
# 72   {'var_smoothing': 2.848035868435799e-07}         0.859259
# 71  {'var_smoothing': 3.5111917342151277e-07}         0.859259
# ..                                        ...              ...
# 3        {'var_smoothing': 0.533669923120631}         0.648148
# 8       {'var_smoothing': 0.1873817422860384}         0.644444
# 7      {'var_smoothing': 0.23101297000831597}         0.644444
# 2        {'var_smoothing': 0.657933224657568}         0.644444
# 0                      {'var_smoothing': 1.0}         0.640741
#
#     std_test_score  rank_test_score
# 49        0.049135                1
# 74        0.043192                1
# 73        0.043192                1
# 72        0.043192                1
# 71        0.043192                1
# ..             ...              ...
# 3         0.074536               96
# 8         0.081481               97
# 7         0.072577               97
# 2         0.066667               97
# 0         0.052509              100
#
# [100 rows x 4 columns]

# %% [markdown]
# # K Neighbors

# %%
#Importa as bibliotecas Pandas e Numpy
import pandas as pd
import numpy as np

# %%
# na_values = substitui o valor '?' (dado faltante) para Nan
dataset = pd.read_csv('heart.dat', sep=' ', na_values='?',names=['Age','Sex','Chest pain type','Resting blood pressure','Serum cholesterol in mg/dl','Fasting blood sugar ','Resting electrocardiographic results','Maximum heart rate achieved','Exercise induced angina','Oldpeak','The slope of the peak','Number of major vessels','num'])
dataset
# Out:
#       Age  Sex  Chest pain type  Resting blood pressure  \
# 70.0  1.0  4.0            130.0                   322.0
# 67.0  0.0  3.0            115.0                   564.0
# 57.0  1.0  2.0            124.0                   261.0
# 64.0  1.0  4.0            128.0                   263.0
# 74.0  0.0  2.0            120.0                   269.0
# ...   ...  ...              ...                     ...
# 52.0  1.0  3.0            172.0                   199.0
# 44.0  1.0  2.0            120.0                   263.0
# 56.0  0.0  2.0            140.0                   294.0
# 57.0  1.0  4.0            140.0                   192.0
# 67.0  1.0  4.0            160.0                   286.0
#
#       Serum cholesterol in mg/dl  Fasting blood sugar   \
# 70.0                         0.0                   2.0
# 67.0                         0.0                   2.0
# 57.0                         0.0                   0.0
# 64.0                         0.0                   0.0
# 74.0                         0.0                   2.0
# ...                          ...                   ...
# 52.0                         1.0                   0.0
# 44.0                         0.0                   0.0
# 56.0                         0.0                   2.0
# 57.0                         0.0                   0.0
# 67.0                         0.0                   2.0
#
#       Resting electrocardiographic results  Maximum heart rate achieved  \
# 70.0                                 109.0                          0.0
# 67.0                                 160.0                          0.0
# 57.0                                 141.0                          0.0
# 64.0                                 105.0                          1.0
# 74.0                                 121.0                          1.0
# ...                                    ...                          ...
# 52.0                                 162.0                          0.0
# 44.0                                 173.0                          0.0
# 56.0                                 153.0                          0.0
# 57.0                                 148.0                          0.0
# 67.0                                 108.0                          1.0
#
#       Exercise induced angina  Oldpeak  The slope of the peak  \
# 70.0                      2.4      2.0                    3.0
# 67.0                      1.6      2.0                    0.0
# 57.0                      0.3      1.0                    0.0
# 64.0                      0.2      2.0                    1.0
# 74.0                      0.2      1.0                    1.0
# ...                       ...      ...                    ...
# 52.0                      0.5      1.0                    0.0
# 44.0                      0.0      1.0                    0.0
# 56.0                      1.3      2.0                    0.0
# 57.0                      0.4      2.0                    0.0
# 67.0                      1.5      2.0                    3.0
#
#       Number of major vessels  num
# 70.0                      3.0    2
# 67.0                      7.0    1
# 57.0                      7.0    2
# 64.0                      7.0    1
# 74.0                      3.0    1
# ...                       ...  ...
# 52.0                      7.0    1
# 44.0                      7.0    1
# 56.0                      3.0    1
# 57.0                      6.0    1
# 67.0                      3.0    2
#
# [270 rows x 13 columns]

# %%
# elimina as linhas com dados faltantes
dataset = dataset.dropna(axis=0)
dataset
# Out:
#       Age  Sex  Chest pain type  Resting blood pressure  \
# 70.0  1.0  4.0            130.0                   322.0
# 67.0  0.0  3.0            115.0                   564.0
# 57.0  1.0  2.0            124.0                   261.0
# 64.0  1.0  4.0            128.0                   263.0
# 74.0  0.0  2.0            120.0                   269.0
# ...   ...  ...              ...                     ...
# 52.0  1.0  3.0            172.0                   199.0
# 44.0  1.0  2.0            120.0                   263.0
# 56.0  0.0  2.0            140.0                   294.0
# 57.0  1.0  4.0            140.0                   192.0
# 67.0  1.0  4.0            160.0                   286.0
#
#       Serum cholesterol in mg/dl  Fasting blood sugar   \
# 70.0                         0.0                   2.0
# 67.0                         0.0                   2.0
# 57.0                         0.0                   0.0
# 64.0                         0.0                   0.0
# 74.0                         0.0                   2.0
# ...                          ...                   ...
# 52.0                         1.0                   0.0
# 44.0                         0.0                   0.0
# 56.0                         0.0                   2.0
# 57.0                         0.0                   0.0
# 67.0                         0.0                   2.0
#
#       Resting electrocardiographic results  Maximum heart rate achieved  \
# 70.0                                 109.0                          0.0
# 67.0                                 160.0                          0.0
# 57.0                                 141.0                          0.0
# 64.0                                 105.0                          1.0
# 74.0                                 121.0                          1.0
# ...                                    ...                          ...
# 52.0                                 162.0                          0.0
# 44.0                                 173.0                          0.0
# 56.0                                 153.0                          0.0
# 57.0                                 148.0                          0.0
# 67.0                                 108.0                          1.0
#
#       Exercise induced angina  Oldpeak  The slope of the peak  \
# 70.0                      2.4      2.0                    3.0
# 67.0                      1.6      2.0                    0.0
# 57.0                      0.3      1.0                    0.0
# 64.0                      0.2      2.0                    1.0
# 74.0                      0.2      1.0                    1.0
# ...                       ...      ...                    ...
# 52.0                      0.5      1.0                    0.0
# 44.0                      0.0      1.0                    0.0
# 56.0                      1.3      2.0                    0.0
# 57.0                      0.4      2.0                    0.0
# 67.0                      1.5      2.0                    3.0
#
#       Number of major vessels  num
# 70.0                      3.0    2
# 67.0                      7.0    1
# 57.0                      7.0    2
# 64.0                      7.0    1
# 74.0                      3.0    1
# ...                       ...  ...
# 52.0                      7.0    1
# 44.0                      7.0    1
# 56.0                      3.0    1
# 57.0                      6.0    1
# 67.0                      3.0    2
#
# [270 rows x 13 columns]

# %%
#Separando as variáveis independentes (conjunto X) e a variável dependente y (que neste caso é a coluna 'num')
X = dataset.loc[:, dataset.columns != 'num'] 
y = np.array(dataset.loc[:, dataset.columns == 'num']).ravel()

# %%
# importa o algoritmo de classifcaçaõ k-vizinhos
from sklearn.neighbors import KNeighborsClassifier
# importa o GridSearchCV
from sklearn.model_selection import GridSearchCV

# no grid coloca os hiperparâmetros do algoritmo que serão testados (dicionário)
# testará o valor de k com os seguintes valores e o hiperparâmetros weights com os valores 'uniform' e 'distance'
parameters = {'n_neighbors' : [1, 3, 5, 7, 9, 11, 13], 'weights' : ['uniform', 'distance']}

# define o algoritmo de classificação que será usado
knn = KNeighborsClassifier()
''' configura o GridSearch com o algoritmo de classificação = knn (instanciado), os parâmetros testados serão os 
    definidos em parameters, usa cross-validation = 10 e a medida de avaliação é a acurácia.'''  
gs = GridSearchCV(knn, parameters, cv=10, scoring='accuracy')
# o grid search treinará todos os modelos conforme a parametrização acima
gs.fit(X, y)
# Out:
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [1, 3, 5, 7, 9, 11, 13],
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy')

# %%
# coloca os resultados num Frame para melhor visulização
results = pd.DataFrame(gs.cv_results_)
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002531      0.000637         0.003126        0.000243
# 1        0.002320      0.000238         0.002646        0.000467
# 2        0.002906      0.000437         0.003616        0.000324
# 3        0.002556      0.000239         0.002735        0.000598
# 4        0.002995      0.000915         0.003836        0.000654
# 5        0.003062      0.000943         0.003955        0.003154
# 6        0.002536      0.000294         0.003509        0.000420
# 7        0.002272      0.000149         0.002487        0.000315
# 8        0.002974      0.000681         0.003515        0.000282
# 9        0.002435      0.000409         0.002548        0.000300
# 10       0.002600      0.000326         0.003847        0.000691
# 11       0.002934      0.000855         0.002962        0.000722
# 12       0.002356      0.000173         0.003156        0.000186
# 13       0.002257      0.000216         0.002447        0.000262
#
#    param_n_neighbors param_weights  \
# 0                  1       uniform
# 1                  1      distance
# 2                  3       uniform
# 3                  3      distance
# 4                  5       uniform
# 5                  5      distance
# 6                  7       uniform
# 7                  7      distance
# 8                  9       uniform
# 9                  9      distance
# 10                11       uniform
# 11                11      distance
# 12                13       uniform
# 13                13      distance
#
#                                         params  split0_test_score  \
# 0     {'n_neighbors': 1, 'weights': 'uniform'}           0.481481
# 1    {'n_neighbors': 1, 'weights': 'distance'}           0.481481
# 2     {'n_neighbors': 3, 'weights': 'uniform'}           0.555556
# 3    {'n_neighbors': 3, 'weights': 'distance'}           0.555556
# 4     {'n_neighbors': 5, 'weights': 'uniform'}           0.629630
# 5    {'n_neighbors': 5, 'weights': 'distance'}           0.629630
# 6     {'n_neighbors': 7, 'weights': 'uniform'}           0.592593
# 7    {'n_neighbors': 7, 'weights': 'distance'}           0.629630
# 8     {'n_neighbors': 9, 'weights': 'uniform'}           0.592593
# 9    {'n_neighbors': 9, 'weights': 'distance'}           0.629630
# 10   {'n_neighbors': 11, 'weights': 'uniform'}           0.518519
# 11  {'n_neighbors': 11, 'weights': 'distance'}           0.518519
# 12   {'n_neighbors': 13, 'weights': 'uniform'}           0.592593
# 13  {'n_neighbors': 13, 'weights': 'distance'}           0.518519
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.703704           0.666667           0.407407
# 1            0.703704           0.666667           0.407407
# 2            0.740741           0.629630           0.481481
# 3            0.740741           0.666667           0.481481
# 4            0.740741           0.592593           0.629630
# 5            0.703704           0.592593           0.592593
# 6            0.740741           0.592593           0.592593
# 7            0.703704           0.592593           0.555556
# 8            0.703704           0.666667           0.629630
# 9            0.666667           0.666667           0.555556
# 10           0.740741           0.703704           0.666667
# 11           0.703704           0.666667           0.666667
# 12           0.740741           0.703704           0.629630
# 13           0.703704           0.703704           0.592593
#
#     split4_test_score  split5_test_score  split6_test_score  \
# 0            0.666667           0.592593           0.666667
# 1            0.666667           0.592593           0.666667
# 2            0.703704           0.592593           0.666667
# 3            0.740741           0.555556           0.703704
# 4            0.666667           0.666667           0.666667
# 5            0.666667           0.592593           0.629630
# 6            0.666667           0.629630           0.592593
# 7            0.666667           0.592593           0.629630
# 8            0.703704           0.666667           0.629630
# 9            0.703704           0.629630           0.555556
# 10           0.666667           0.666667           0.629630
# 11           0.666667           0.666667           0.555556
# 12           0.666667           0.703704           0.555556
# 13           0.666667           0.666667           0.555556
#
#     split7_test_score  split8_test_score  split9_test_score  mean_test_score  \
# 0            0.777778           0.592593           0.629630         0.618519
# 1            0.777778           0.592593           0.629630         0.618519
# 2            0.629630           0.703704           0.555556         0.625926
# 3            0.629630           0.740741           0.592593         0.640741
# 4            0.629630           0.814815           0.555556         0.659259
# 5            0.629630           0.814815           0.555556         0.640741
# 6            0.703704           0.777778           0.592593         0.648148
# 7            0.703704           0.814815           0.592593         0.648148
# 8            0.740741           0.703704           0.629630         0.666667
# 9            0.740741           0.740741           0.629630         0.651852
# 10           0.740741           0.666667           0.629630         0.662963
# 11           0.740741           0.666667           0.666667         0.651852
# 12           0.777778           0.703704           0.518519         0.659259
# 13           0.740741           0.666667           0.629630         0.644444
#
#     std_test_score  rank_test_score
# 0         0.102171               13
# 1         0.102171               13
# 2         0.076712               12
# 3         0.087724               10
# 4         0.069881                3
# 5         0.070370               11
# 6         0.066769                7
# 7         0.072672                7
# 8         0.043823                1
# 9         0.062416                5
# 10        0.060745                2
# 11        0.062416                5
# 12        0.079089                3
# 13        0.066667                9

# %%
#criar uma visão para facilitar a visualização dos resultados, e ordenar os resultados conforme os resultados.
view = ['params', 'mean_test_score', 'std_test_score', 'rank_test_score']
results[view].sort_values(by='rank_test_score')
# Out:
#                                         params  mean_test_score  \
# 8     {'n_neighbors': 9, 'weights': 'uniform'}         0.666667
# 10   {'n_neighbors': 11, 'weights': 'uniform'}         0.662963
# 4     {'n_neighbors': 5, 'weights': 'uniform'}         0.659259
# 12   {'n_neighbors': 13, 'weights': 'uniform'}         0.659259
# 9    {'n_neighbors': 9, 'weights': 'distance'}         0.651852
# 11  {'n_neighbors': 11, 'weights': 'distance'}         0.651852
# 6     {'n_neighbors': 7, 'weights': 'uniform'}         0.648148
# 7    {'n_neighbors': 7, 'weights': 'distance'}         0.648148
# 13  {'n_neighbors': 13, 'weights': 'distance'}         0.644444
# 3    {'n_neighbors': 3, 'weights': 'distance'}         0.640741
# 5    {'n_neighbors': 5, 'weights': 'distance'}         0.640741
# 2     {'n_neighbors': 3, 'weights': 'uniform'}         0.625926
# 0     {'n_neighbors': 1, 'weights': 'uniform'}         0.618519
# 1    {'n_neighbors': 1, 'weights': 'distance'}         0.618519
#
#     std_test_score  rank_test_score
# 8         0.043823                1
# 10        0.060745                2
# 4         0.069881                3
# 12        0.079089                3
# 9         0.062416                5
# 11        0.062416                5
# 6         0.066769                7
# 7         0.072672                7
# 13        0.066667                9
# 3         0.087724               10
# 5         0.070370               11
# 2         0.076712               12
# 0         0.102171               13
# 1         0.102171               13

# %% [markdown]
# # Calculo da Diferenca Absoluta

# %% [markdown]
# Observando os resultados, podemos ver que os metodos MLP e Arvore de Decisao tem as melhores performances, logo temos que calcular a diferenca absoluta para ver qual dos dois e de fato o melhor

# %%
#Calculo do desvio padrao
import math
Dp = math.sqrt(((4.444444e-02)*(4.444444e-02) + (0.049135)*(0.049135))/2)
#Calculo da media
media = (0.829630 - 0.859259)
#calcula da Diferenca Absoluta
DA = media/Dp
print(DA)
#MLP < Naive Bayes
# Out:
# -0.632443409811199

# %% [markdown]
# Conclusao: O Naive Bayes tem uma melhor performance do que o MLP e o restante dos algoritmos.
