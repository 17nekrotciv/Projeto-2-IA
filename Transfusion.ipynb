# %% [markdown]
# # Arvore de Decisao

# %%
#Importa as bibliotecas Pandas e Numpy
import pandas as pd
import numpy as np

# %%
# na_values = substitui o valor '?' (dado faltante) para Nan
dataset = pd.read_csv('transfusion.data', sep=',', na_values='?')
dataset
# Out:
#                   Frequency (times)  Monetary (c.c. blood)  Time (months)  \
# Recency (months)
# 2                                50                  12500             98
# 0                                13                   3250             28
# 1                                16                   4000             35
# 2                                20                   5000             45
# 1                                24                   6000             77
# ...                             ...                    ...            ...
# 23                                2                    500             38
# 21                                2                    500             52
# 23                                3                    750             62
# 39                                1                    250             39
# 72                                1                    250             72
#
#                   whether he/she donated blood in March 2007
# Recency (months)
# 2                                                          1
# 0                                                          1
# 1                                                          1
# 2                                                          1
# 1                                                          0
# ...                                                      ...
# 23                                                         0
# 21                                                         0
# 23                                                         0
# 39                                                         0
# 72                                                         0
#
# [748 rows x 4 columns]

# %%
# elimina as linhas com dados faltantes
dataset = dataset.dropna(axis=0)
dataset
# Out:
#                   Frequency (times)  Monetary (c.c. blood)  Time (months)  \
# Recency (months)
# 2                                50                  12500             98
# 0                                13                   3250             28
# 1                                16                   4000             35
# 2                                20                   5000             45
# 1                                24                   6000             77
# ...                             ...                    ...            ...
# 23                                2                    500             38
# 21                                2                    500             52
# 23                                3                    750             62
# 39                                1                    250             39
# 72                                1                    250             72
#
#                   whether he/she donated blood in March 2007
# Recency (months)
# 2                                                          1
# 0                                                          1
# 1                                                          1
# 2                                                          1
# 1                                                          0
# ...                                                      ...
# 23                                                         0
# 21                                                         0
# 23                                                         0
# 39                                                         0
# 72                                                         0
#
# [748 rows x 4 columns]

# %%
#Separando as variáveis independentes (conjunto X) e a variável dependente y (que neste caso é a coluna 'whether he/she donated blood in March 2007')
X = dataset.loc[:, dataset.columns != 'whether he/she donated blood in March 2007'] 
y = np.array(dataset.loc[:, dataset.columns == 'whether he/she donated blood in March 2007']).ravel()

# %%
#Define os parametros do metodo de Arvore de Decisao
parameters= {'criterion':['gini'],'max_depth':[4,5,6,7,8,9,10,11,12,15,20,30,40,50,70,90,120,150], 'random_state': [56]}

# %%
# importa o método do sklearn que separa em conjunto de treino e teste
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.26, stratify=y, random_state=56)

# %%
# importa o GridSearchCV
from sklearn.model_selection import GridSearchCV
# importa a arvore de decisão
from sklearn.tree import DecisionTreeClassifier
# instancia o classificador 
clf = DecisionTreeClassifier()
gs_tree = GridSearchCV(clf,parameters, cv = 10, scoring = 'accuracy')
# o grid search treinará todos os modelos conforme a parametrização acima
gs_tree.fit(X,y)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini'],
#                          'max_depth': [4, 5, 6, 7, 8, 9, 10, 11, 12, 15, 20, 30,
#                                        40, 50, 70, 90, 120, 150],
#                          'random_state': [56]},
#              scoring='accuracy')

# %%
# coloca os resultados num Frame para melhor visulização
results = pd.DataFrame(gs_tree.cv_results_)
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.007483      0.006762         0.002530        0.000505
# 1        0.004576      0.001454         0.005490        0.005044
# 2        0.006132      0.004232         0.002167        0.000134
# 3        0.003838      0.000201         0.003878        0.005328
# 4        0.003845      0.000211         0.002840        0.002171
# 5        0.003979      0.000141         0.002946        0.001531
# 6        0.004694      0.001541         0.002159        0.000127
# 7        0.005490      0.004508         0.002558        0.001022
# 8        0.008431      0.007525         0.002203        0.000146
# 9        0.009167      0.007350         0.003856        0.003329
# 10       0.004846      0.002276         0.002186        0.000137
# 11       0.005124      0.003098         0.002196        0.000296
# 12       0.006126      0.003249         0.003892        0.002850
# 13       0.005031      0.001687         0.002218        0.000190
# 14       0.004003      0.000149         0.003555        0.002875
# 15       0.004976      0.002301         0.002168        0.000088
# 16       0.004385      0.000508         0.002631        0.001013
# 17       0.004876      0.002293         0.002136        0.000108
#
#    param_criterion param_max_depth param_random_state  \
# 0             gini               4                 56
# 1             gini               5                 56
# 2             gini               6                 56
# 3             gini               7                 56
# 4             gini               8                 56
# 5             gini               9                 56
# 6             gini              10                 56
# 7             gini              11                 56
# 8             gini              12                 56
# 9             gini              15                 56
# 10            gini              20                 56
# 11            gini              30                 56
# 12            gini              40                 56
# 13            gini              50                 56
# 14            gini              70                 56
# 15            gini              90                 56
# 16            gini             120                 56
# 17            gini             150                 56
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_depth': 4, 'random_...           0.400000
# 1   {'criterion': 'gini', 'max_depth': 5, 'random_...           0.533333
# 2   {'criterion': 'gini', 'max_depth': 6, 'random_...           0.520000
# 3   {'criterion': 'gini', 'max_depth': 7, 'random_...           0.506667
# 4   {'criterion': 'gini', 'max_depth': 8, 'random_...           0.520000
# 5   {'criterion': 'gini', 'max_depth': 9, 'random_...           0.520000
# 6   {'criterion': 'gini', 'max_depth': 10, 'random...           0.506667
# 7   {'criterion': 'gini', 'max_depth': 11, 'random...           0.493333
# 8   {'criterion': 'gini', 'max_depth': 12, 'random...           0.520000
# 9   {'criterion': 'gini', 'max_depth': 15, 'random...           0.506667
# 10  {'criterion': 'gini', 'max_depth': 20, 'random...           0.493333
# 11  {'criterion': 'gini', 'max_depth': 30, 'random...           0.493333
# 12  {'criterion': 'gini', 'max_depth': 40, 'random...           0.493333
# 13  {'criterion': 'gini', 'max_depth': 50, 'random...           0.493333
# 14  {'criterion': 'gini', 'max_depth': 70, 'random...           0.493333
# 15  {'criterion': 'gini', 'max_depth': 90, 'random...           0.493333
# 16  {'criterion': 'gini', 'max_depth': 120, 'rando...           0.493333
# 17  {'criterion': 'gini', 'max_depth': 150, 'rando...           0.493333
#
#     split1_test_score  ...  split3_test_score  split4_test_score  \
# 0            0.813333  ...           0.760000           0.746667
# 1            0.813333  ...           0.746667           0.746667
# 2            0.773333  ...           0.733333           0.746667
# 3            0.786667  ...           0.666667           0.680000
# 4            0.733333  ...           0.666667           0.706667
# 5            0.773333  ...           0.666667           0.706667
# 6            0.773333  ...           0.653333           0.720000
# 7            0.746667  ...           0.653333           0.693333
# 8            0.720000  ...           0.653333           0.680000
# 9            0.720000  ...           0.613333           0.693333
# 10           0.720000  ...           0.626667           0.693333
# 11           0.720000  ...           0.626667           0.693333
# 12           0.720000  ...           0.626667           0.693333
# 13           0.720000  ...           0.626667           0.693333
# 14           0.720000  ...           0.626667           0.693333
# 15           0.720000  ...           0.626667           0.693333
# 16           0.720000  ...           0.626667           0.693333
# 17           0.720000  ...           0.626667           0.693333
#
#     split5_test_score  split6_test_score  split7_test_score  \
# 0            0.760000           0.666667           0.826667
# 1            0.746667           0.746667           0.826667
# 2            0.720000           0.720000           0.826667
# 3            0.706667           0.720000           0.813333
# 4            0.706667           0.760000           0.773333
# 5            0.706667           0.760000           0.786667
# 6            0.693333           0.746667           0.760000
# 7            0.720000           0.746667           0.786667
# 8            0.720000           0.760000           0.800000
# 9            0.720000           0.760000           0.800000
# 10           0.720000           0.773333           0.773333
# 11           0.720000           0.773333           0.773333
# 12           0.720000           0.773333           0.773333
# 13           0.720000           0.773333           0.773333
# 14           0.720000           0.773333           0.773333
# 15           0.720000           0.773333           0.773333
# 16           0.720000           0.773333           0.773333
# 17           0.720000           0.773333           0.773333
#
#     split8_test_score  split9_test_score  mean_test_score  std_test_score  \
# 0            0.770270           0.770270         0.728721        0.116783
# 1            0.743243           0.770270         0.744685        0.075892
# 2            0.743243           0.770270         0.731351        0.076479
# 3            0.729730           0.770270         0.715333        0.082787
# 4            0.743243           0.783784         0.712703        0.072164
# 5            0.729730           0.783784         0.714018        0.074881
# 6            0.716216           0.783784         0.704667        0.076331
# 7            0.689189           0.783784         0.703297        0.080391
# 8            0.675676           0.783784         0.700613        0.075518
# 9            0.702703           0.783784         0.699315        0.081486
# 10           0.689189           0.783784         0.696631        0.081705
# 11           0.689189           0.783784         0.696631        0.081705
# 12           0.689189           0.783784         0.696631        0.081705
# 13           0.689189           0.783784         0.696631        0.081705
# 14           0.689189           0.783784         0.696631        0.081705
# 15           0.689189           0.783784         0.696631        0.081705
# 16           0.689189           0.783784         0.696631        0.081705
# 17           0.689189           0.783784         0.696631        0.081705
#
#     rank_test_score
# 0                 3
# 1                 1
# 2                 2
# 3                 4
# 4                 6
# 5                 5
# 6                 7
# 7                 8
# 8                 9
# 9                10
# 10               11
# 11               11
# 12               11
# 13               11
# 14               11
# 15               11
# 16               11
# 17               11
#
# [18 rows x 21 columns]

# %%
#criar uma visão para facilitar a visualização dos resultados, e ordenar os resultados conforme os resultados.
view = ['params', 'mean_test_score', 'std_test_score', 'rank_test_score']
results[view].sort_values(by='rank_test_score')
# Out:
#                                                params  mean_test_score  \
# 1   {'criterion': 'gini', 'max_depth': 5, 'random_...         0.744685
# 2   {'criterion': 'gini', 'max_depth': 6, 'random_...         0.731351
# 0   {'criterion': 'gini', 'max_depth': 4, 'random_...         0.728721
# 3   {'criterion': 'gini', 'max_depth': 7, 'random_...         0.715333
# 5   {'criterion': 'gini', 'max_depth': 9, 'random_...         0.714018
# 4   {'criterion': 'gini', 'max_depth': 8, 'random_...         0.712703
# 6   {'criterion': 'gini', 'max_depth': 10, 'random...         0.704667
# 7   {'criterion': 'gini', 'max_depth': 11, 'random...         0.703297
# 8   {'criterion': 'gini', 'max_depth': 12, 'random...         0.700613
# 9   {'criterion': 'gini', 'max_depth': 15, 'random...         0.699315
# 10  {'criterion': 'gini', 'max_depth': 20, 'random...         0.696631
# 11  {'criterion': 'gini', 'max_depth': 30, 'random...         0.696631
# 12  {'criterion': 'gini', 'max_depth': 40, 'random...         0.696631
# 13  {'criterion': 'gini', 'max_depth': 50, 'random...         0.696631
# 14  {'criterion': 'gini', 'max_depth': 70, 'random...         0.696631
# 15  {'criterion': 'gini', 'max_depth': 90, 'random...         0.696631
# 16  {'criterion': 'gini', 'max_depth': 120, 'rando...         0.696631
# 17  {'criterion': 'gini', 'max_depth': 150, 'rando...         0.696631
#
#     std_test_score  rank_test_score
# 1         0.075892                1
# 2         0.076479                2
# 0         0.116783                3
# 3         0.082787                4
# 5         0.074881                5
# 4         0.072164                6
# 6         0.076331                7
# 7         0.080391                8
# 8         0.075518                9
# 9         0.081486               10
# 10        0.081705               11
# 11        0.081705               11
# 12        0.081705               11
# 13        0.081705               11
# 14        0.081705               11
# 15        0.081705               11
# 16        0.081705               11
# 17        0.081705               11

# %% [markdown]
# # Multilayer-Perceptron (redes neurais)

# %%
#Importa as bibliotecas Pandas e Numpy
import pandas as pd
import numpy as np

# %%
# na_values = substitui o valor '?' (dado faltante) para Nan
dataset = pd.read_csv('transfusion.data', sep=',', na_values='?')
dataset
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                   2                 50                  12500
# 1                   0                 13                   3250
# 2                   1                 16                   4000
# 3                   2                 20                   5000
# 4                   1                 24                   6000
# ..                ...                ...                    ...
# 743                23                  2                    500
# 744                21                  2                    500
# 745                23                  3                    750
# 746                39                  1                    250
# 747                72                  1                    250
#
#      Time (months)  whether he/she donated blood in March 2007
# 0               98                                           1
# 1               28                                           1
# 2               35                                           1
# 3               45                                           1
# 4               77                                           0
# ..             ...                                         ...
# 743             38                                           0
# 744             52                                           0
# 745             62                                           0
# 746             39                                           0
# 747             72                                           0
#
# [748 rows x 5 columns]

# %%
# elimina as linhas com dados faltantes
dataset = dataset.dropna(axis=0)
dataset
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                   2                 50                  12500
# 1                   0                 13                   3250
# 2                   1                 16                   4000
# 3                   2                 20                   5000
# 4                   1                 24                   6000
# ..                ...                ...                    ...
# 743                23                  2                    500
# 744                21                  2                    500
# 745                23                  3                    750
# 746                39                  1                    250
# 747                72                  1                    250
#
#      Time (months)  whether he/she donated blood in March 2007
# 0               98                                           1
# 1               28                                           1
# 2               35                                           1
# 3               45                                           1
# 4               77                                           0
# ..             ...                                         ...
# 743             38                                           0
# 744             52                                           0
# 745             62                                           0
# 746             39                                           0
# 747             72                                           0
#
# [748 rows x 5 columns]

# %%
#Separando as variáveis independentes (conjunto X) e a variável dependente y (que neste caso é a coluna 'whether he/she donated blood in March 2007')
X = dataset.loc[:, dataset.columns != 'whether he/she donated blood in March 2007'] 
y = np.array(dataset.loc[:, dataset.columns == 'whether he/she donated blood in March 2007']).ravel()

# %%
# importa o algoritmo de classificação Multilayer-Perceptron (redes neurais)
from sklearn.neural_network import MLPClassifier
# importa o GridSearchCV
from sklearn.model_selection import GridSearchCV

# na MLP um parâmetro a ser testado é a quantidade de neurônios na camada escondida, 
# onde utilzamos uma tupla para representar a camada escondida.
# Por exemplo:
# (5) - Cinco neurônios e uma camada escondida
# (8, 5) - Oito neurônios na primeira camada escondida e cinco neurônios na segunda camada escondida.
# Interessante nesse projeto utilizar no máximo duas camadas para verificação 
# Quanto mais camadas e neurônios maior o tempo de processamento do algoritmo
parameters = {'hidden_layer_sizes' : [(5), (8), (15), (5, 3), (8, 5), (10, 5)],
              'max_iter' : [3000], 'random_state' : [56]}

# define o algoritmo de classificação que será usado
mlp = MLPClassifier()
gs_mlp = GridSearchCV(mlp, parameters, cv=10, scoring='accuracy')
# o grid search treinará todos os modelos conforme a parametrização acima
gs_mlp.fit(X, y)
# Out:
# GridSearchCV(cv=10, estimator=MLPClassifier(),
#              param_grid={'hidden_layer_sizes': [5, 8, 15, (5, 3), (8, 5),
#                                                 (10, 5)],
#                          'max_iter': [3000], 'random_state': [56]},
#              scoring='accuracy')

# %%
#criar uma visão para facilitar a visualização dos resultados, e ordenar os resultados conforme os resultados.
view = ['params', 'mean_test_score', 'std_test_score', 'rank_test_score']
results = pd.DataFrame(gs_mlp.cv_results_)
results[view].sort_values(by='rank_test_score')
# Out:
#                                               params  mean_test_score  \
# 1  {'hidden_layer_sizes': 8, 'max_iter': 3000, 'r...         0.791423
# 3  {'hidden_layer_sizes': (5, 3), 'max_iter': 300...         0.762054
# 5  {'hidden_layer_sizes': (10, 5), 'max_iter': 30...         0.758036
# 2  {'hidden_layer_sizes': 15, 'max_iter': 3000, '...         0.754054
# 4  {'hidden_layer_sizes': (8, 5), 'max_iter': 300...         0.706198
# 0  {'hidden_layer_sizes': 5, 'max_iter': 3000, 'r...         0.237946
#
#    std_test_score  rank_test_score
# 1        0.046356                1
# 3        0.004108                2
# 5        0.014869                3
# 2        0.130449                4
# 4        0.115140                5
# 0        0.004108                6

# %% [markdown]
# # Naive Bayes

# %%
#Importa as bibliotecas Pandas e Numpy
import pandas as pd
import numpy as np

# %%
# na_values = substitui o valor '?' (dado faltante) para Nan
dataset = pd.read_csv('transfusion.data', sep=',', na_values='?')
dataset
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                   2                 50                  12500
# 1                   0                 13                   3250
# 2                   1                 16                   4000
# 3                   2                 20                   5000
# 4                   1                 24                   6000
# ..                ...                ...                    ...
# 743                23                  2                    500
# 744                21                  2                    500
# 745                23                  3                    750
# 746                39                  1                    250
# 747                72                  1                    250
#
#      Time (months)  whether he/she donated blood in March 2007
# 0               98                                           1
# 1               28                                           1
# 2               35                                           1
# 3               45                                           1
# 4               77                                           0
# ..             ...                                         ...
# 743             38                                           0
# 744             52                                           0
# 745             62                                           0
# 746             39                                           0
# 747             72                                           0
#
# [748 rows x 5 columns]

# %%
# elimina as linhas com dados faltantes
dataset = dataset.dropna(axis=0)
dataset
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                   2                 50                  12500
# 1                   0                 13                   3250
# 2                   1                 16                   4000
# 3                   2                 20                   5000
# 4                   1                 24                   6000
# ..                ...                ...                    ...
# 743                23                  2                    500
# 744                21                  2                    500
# 745                23                  3                    750
# 746                39                  1                    250
# 747                72                  1                    250
#
#      Time (months)  whether he/she donated blood in March 2007
# 0               98                                           1
# 1               28                                           1
# 2               35                                           1
# 3               45                                           1
# 4               77                                           0
# ..             ...                                         ...
# 743             38                                           0
# 744             52                                           0
# 745             62                                           0
# 746             39                                           0
# 747             72                                           0
#
# [748 rows x 5 columns]

# %%
#Separando as variáveis independentes (conjunto X) e a variável dependente y (que neste caso é a coluna 'whether he/she donated blood in March 2007')
X = dataset.loc[:, dataset.columns != 'whether he/she donated blood in March 2007'] 
y = np.array(dataset.loc[:, dataset.columns == 'whether he/she donated blood in March 2007']).ravel()

# %%
#Define os parametros do metodo Naive Bayes
param = {'var_smoothing': np.logspace(0,-9, num=100)}

# %%
# importa o método do sklearn que separa em conjunto de treino e teste
from sklearn.model_selection import train_test_split
# importa o algoritmo Naive Bayes 
from sklearn.naive_bayes import GaussianNB
# importa o GridSearchCV
from sklearn.model_selection import GridSearchCV

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.45, random_state=56)
# instancia o classificador
gnb = GaussianNB()
gs_NB = GridSearchCV(gnb, param, cv = 10, scoring = 'accuracy')
# o grid search treinará todos os modelos conforme a parametrização acima
gs_NB.fit(X,y)
# Out:
# GridSearchCV(cv=10, estimator=GaussianNB(),
#              param_grid={'var_smoothing': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#        4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#        1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#        8.11130831e-02, 6.57933225e-02, 5.33669923e-02, 4.32876128e-02,
#        3.51119173e-02, 2.84803587e-02, 2.3...
#        1.23284674e-07, 1.00000000e-07, 8.11130831e-08, 6.57933225e-08,
#        5.33669923e-08, 4.32876128e-08, 3.51119173e-08, 2.84803587e-08,
#        2.31012970e-08, 1.87381742e-08, 1.51991108e-08, 1.23284674e-08,
#        1.00000000e-08, 8.11130831e-09, 6.57933225e-09, 5.33669923e-09,
#        4.32876128e-09, 3.51119173e-09, 2.84803587e-09, 2.31012970e-09,
#        1.87381742e-09, 1.51991108e-09, 1.23284674e-09, 1.00000000e-09])},
#              scoring='accuracy')

# %%
#criar uma visão para facilitar a visualização dos resultados, e ordenar os resultados conforme os resultados.
view = ['params', 'mean_test_score', 'std_test_score', 'rank_test_score']
results = pd.DataFrame(gs_NB.cv_results_)
results[view].sort_values(by='rank_test_score')
# Out:
#                                       params  mean_test_score  std_test_score  \
# 1      {'var_smoothing': 0.8111308307896871}         0.768721        0.021462
# 2       {'var_smoothing': 0.657933224657568}         0.768703        0.021661
# 3       {'var_smoothing': 0.533669923120631}         0.768703        0.021661
# 5      {'var_smoothing': 0.3511191734215131}         0.767369        0.021745
# 0                     {'var_smoothing': 1.0}         0.766054        0.022361
# ..                                       ...              ...             ...
# 78  {'var_smoothing': 8.111308307896873e-08}         0.747351        0.034813
# 77                  {'var_smoothing': 1e-07}         0.747351        0.034813
# 65  {'var_smoothing': 1.232846739442066e-06}         0.747351        0.031601
# 86  {'var_smoothing': 1.519911082952933e-08}         0.747351        0.034813
# 99                  {'var_smoothing': 1e-09}         0.747351        0.034813
#
#     rank_test_score
# 1                 1
# 2                 2
# 3                 2
# 5                 4
# 0                 5
# ..              ...
# 78               77
# 77               77
# 65               77
# 86               77
# 99               77
#
# [100 rows x 4 columns]

# %% [markdown]
# # K Neighbors

# %%
#Importa as bibliotecas Pandas e Numpy
import pandas as pd
import numpy as np

# %%
# na_values = substitui o valor '?' (dado faltante) para Nan
dataset = pd.read_csv('transfusion.data', sep=',', na_values='?')
dataset
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                   2                 50                  12500
# 1                   0                 13                   3250
# 2                   1                 16                   4000
# 3                   2                 20                   5000
# 4                   1                 24                   6000
# ..                ...                ...                    ...
# 743                23                  2                    500
# 744                21                  2                    500
# 745                23                  3                    750
# 746                39                  1                    250
# 747                72                  1                    250
#
#      Time (months)  whether he/she donated blood in March 2007
# 0               98                                           1
# 1               28                                           1
# 2               35                                           1
# 3               45                                           1
# 4               77                                           0
# ..             ...                                         ...
# 743             38                                           0
# 744             52                                           0
# 745             62                                           0
# 746             39                                           0
# 747             72                                           0
#
# [748 rows x 5 columns]

# %%
# elimina as linhas com dados faltantes
dataset = dataset.dropna(axis=0)
dataset
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                   2                 50                  12500
# 1                   0                 13                   3250
# 2                   1                 16                   4000
# 3                   2                 20                   5000
# 4                   1                 24                   6000
# ..                ...                ...                    ...
# 743                23                  2                    500
# 744                21                  2                    500
# 745                23                  3                    750
# 746                39                  1                    250
# 747                72                  1                    250
#
#      Time (months)  whether he/she donated blood in March 2007
# 0               98                                           1
# 1               28                                           1
# 2               35                                           1
# 3               45                                           1
# 4               77                                           0
# ..             ...                                         ...
# 743             38                                           0
# 744             52                                           0
# 745             62                                           0
# 746             39                                           0
# 747             72                                           0
#
# [748 rows x 5 columns]

# %%
#Separando as variáveis independentes (conjunto X) e a variável dependente y (que neste caso é a coluna 'whether he/she donated blood in March 2007')
X = dataset.loc[:, dataset.columns != 'whether he/she donated blood in March 2007'] 
y = np.array(dataset.loc[:, dataset.columns == 'whether he/she donated blood in March 2007']).ravel()

# %%
# importa o algoritmo de classifcaçaõ k-vizinhos
from sklearn.neighbors import KNeighborsClassifier
# importa o GridSearchCV
from sklearn.model_selection import GridSearchCV

# no grid coloca os hiperparâmetros do algoritmo que serão testados (dicionário)
# testará o valor de k com os seguintes valores e o hiperparâmetros weights com os valores 'uniform' e 'distance'
parameters = {'n_neighbors' : [1, 3, 5, 7, 9, 11, 13], 'weights' : ['uniform', 'distance']}

# define o algoritmo de classificação que será usado
knn = KNeighborsClassifier()
''' configura o GridSearch com o algoritmo de classificação = knn (instanciado), os parâmetros testados serão os 
    definidos em parameters, usa cross-validation = 10 e a medida de avaliação é a acurácia.'''  
gs = GridSearchCV(knn, parameters, cv=10, scoring='accuracy')
# o grid search treinará todos os modelos conforme a parametrização acima
gs.fit(X, y)
# Out:
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [1, 3, 5, 7, 9, 11, 13],
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy')

# %%
# coloca os resultados num Frame para melhor visulização
results = pd.DataFrame(gs.cv_results_)
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002233      0.000552         0.004630        0.001555
# 1        0.002011      0.000305         0.002090        0.000470
# 2        0.001951      0.000092         0.003789        0.000117
# 3        0.002181      0.000547         0.002195        0.000396
# 4        0.001913      0.000030         0.003831        0.000091
# 5        0.001941      0.000072         0.001968        0.000019
# 6        0.002202      0.000440         0.004393        0.000736
# 7        0.001938      0.000068         0.002046        0.000068
# 8        0.001949      0.000108         0.003957        0.000373
# 9        0.002263      0.000558         0.002314        0.000477
# 10       0.002164      0.000386         0.004609        0.000953
# 11       0.001939      0.000071         0.002060        0.000026
# 12       0.001994      0.000115         0.003920        0.000093
# 13       0.001941      0.000028         0.002224        0.000218
#
#    param_n_neighbors param_weights  \
# 0                  1       uniform
# 1                  1      distance
# 2                  3       uniform
# 3                  3      distance
# 4                  5       uniform
# 5                  5      distance
# 6                  7       uniform
# 7                  7      distance
# 8                  9       uniform
# 9                  9      distance
# 10                11       uniform
# 11                11      distance
# 12                13       uniform
# 13                13      distance
#
#                                         params  split0_test_score  \
# 0     {'n_neighbors': 1, 'weights': 'uniform'}           0.333333
# 1    {'n_neighbors': 1, 'weights': 'distance'}           0.333333
# 2     {'n_neighbors': 3, 'weights': 'uniform'}           0.426667
# 3    {'n_neighbors': 3, 'weights': 'distance'}           0.373333
# 4     {'n_neighbors': 5, 'weights': 'uniform'}           0.413333
# 5    {'n_neighbors': 5, 'weights': 'distance'}           0.386667
# 6     {'n_neighbors': 7, 'weights': 'uniform'}           0.413333
# 7    {'n_neighbors': 7, 'weights': 'distance'}           0.413333
# 8     {'n_neighbors': 9, 'weights': 'uniform'}           0.480000
# 9    {'n_neighbors': 9, 'weights': 'distance'}           0.426667
# 10   {'n_neighbors': 11, 'weights': 'uniform'}           0.480000
# 11  {'n_neighbors': 11, 'weights': 'distance'}           0.426667
# 12   {'n_neighbors': 13, 'weights': 'uniform'}           0.493333
# 13  {'n_neighbors': 13, 'weights': 'distance'}           0.413333
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.320000           0.493333           0.533333
# 1            0.320000           0.493333           0.533333
# 2            0.373333           0.520000           0.720000
# 3            0.360000           0.493333           0.653333
# 4            0.453333           0.533333           0.746667
# 5            0.360000           0.520000           0.680000
# 6            0.480000           0.586667           0.733333
# 7            0.373333           0.560000           0.706667
# 8            0.480000           0.573333           0.733333
# 9            0.373333           0.560000           0.680000
# 10           0.560000           0.560000           0.773333
# 11           0.373333           0.560000           0.706667
# 12           0.800000           0.573333           0.773333
# 13           0.640000           0.560000           0.720000
#
#     split4_test_score  split5_test_score  split6_test_score  \
# 0            0.546667           0.653333           0.613333
# 1            0.546667           0.653333           0.613333
# 2            0.760000           0.746667           0.706667
# 3            0.693333           0.746667           0.733333
# 4            0.773333           0.760000           0.706667
# 5            0.720000           0.746667           0.746667
# 6            0.746667           0.760000           0.653333
# 7            0.706667           0.746667           0.733333
# 8            0.746667           0.773333           0.733333
# 9            0.720000           0.746667           0.706667
# 10           0.773333           0.746667           0.733333
# 11           0.720000           0.746667           0.733333
# 12           0.773333           0.760000           0.733333
# 13           0.720000           0.746667           0.720000
#
#     split7_test_score  split8_test_score  split9_test_score  mean_test_score  \
# 0            0.866667           0.635135           0.797297         0.579243
# 1            0.866667           0.635135           0.797297         0.579243
# 2            0.720000           0.729730           0.797297         0.650036
# 3            0.800000           0.689189           0.783784         0.632631
# 4            0.813333           0.729730           0.770270         0.670000
# 5            0.813333           0.702703           0.756757         0.643279
# 6            0.773333           0.729730           0.770270         0.664667
# 7            0.813333           0.716216           0.756757         0.652631
# 8            0.760000           0.716216           0.770270         0.676649
# 9            0.813333           0.716216           0.756757         0.649964
# 10           0.760000           0.729730           0.770270         0.688667
# 11           0.813333           0.716216           0.756757         0.655297
# 12           0.746667           0.729730           0.770270         0.715333
# 13           0.813333           0.729730           0.756757         0.681982
#
#     std_test_score  rank_test_score
# 0         0.166782               13
# 1         0.166782               13
# 2         0.143468                9
# 3         0.155655               12
# 4         0.138444                5
# 5         0.153373               11
# 6         0.122965                6
# 7         0.143442                8
# 8         0.112236                4
# 9         0.139763               10
# 10        0.104777                2
# 11        0.141810                7
# 12        0.094800                1
# 13        0.110661                3

# %%
#criar uma visão para facilitar a visualização dos resultados, e ordenar os resultados conforme os resultados.
view = ['params', 'mean_test_score', 'std_test_score', 'rank_test_score']
results[view].sort_values(by='rank_test_score')
# Out:
#                                         params  mean_test_score  \
# 12   {'n_neighbors': 13, 'weights': 'uniform'}         0.715333
# 10   {'n_neighbors': 11, 'weights': 'uniform'}         0.688667
# 13  {'n_neighbors': 13, 'weights': 'distance'}         0.681982
# 8     {'n_neighbors': 9, 'weights': 'uniform'}         0.676649
# 4     {'n_neighbors': 5, 'weights': 'uniform'}         0.670000
# 6     {'n_neighbors': 7, 'weights': 'uniform'}         0.664667
# 11  {'n_neighbors': 11, 'weights': 'distance'}         0.655297
# 7    {'n_neighbors': 7, 'weights': 'distance'}         0.652631
# 2     {'n_neighbors': 3, 'weights': 'uniform'}         0.650036
# 9    {'n_neighbors': 9, 'weights': 'distance'}         0.649964
# 5    {'n_neighbors': 5, 'weights': 'distance'}         0.643279
# 3    {'n_neighbors': 3, 'weights': 'distance'}         0.632631
# 0     {'n_neighbors': 1, 'weights': 'uniform'}         0.579243
# 1    {'n_neighbors': 1, 'weights': 'distance'}         0.579243
#
#     std_test_score  rank_test_score
# 12        0.094800                1
# 10        0.104777                2
# 13        0.110661                3
# 8         0.112236                4
# 4         0.138444                5
# 6         0.122965                6
# 11        0.141810                7
# 7         0.143442                8
# 2         0.143468                9
# 9         0.139763               10
# 5         0.153373               11
# 3         0.155655               12
# 0         0.166782               13
# 1         0.166782               13

# %% [markdown]
# # Calculo da Diferenca Absoluta

# %% [markdown]
# Observando os resultados, podemos ver que os metodos MLP e Arvore de Decisao tem as melhores performances, logo temos que calcular a diferenca absoluta para ver qual dos dois e de fato o melhor

# %%
#Calculo do desvio padrao
import math
Dp = math.sqrt(((0.046356)*(0.046356) + (0.021462)*(0.021462))/2)
#Calculo da media
media = (0.791423 - 0.768721)
#calcula da Diferenca Absoluta
DA = media/Dp
print(DA)
#MLP > Naive Bayes
# Out:
# 0.6284934912655427

# %% [markdown]
# Conclusao: O MLP tem uma melhor performance do que a Arvore de decisao e o restante dos algoritmos
