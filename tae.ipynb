# %% [markdown]
# # Arvore de Decisao

# %%
#Importa as bibliotecas Pandas e Numpy
import pandas as pd
import numpy as np

# %%
# na_values = substitui o valor '?' (dado faltante) para Nan
dataset = pd.read_csv('tae.data', sep=',',  index_col=0, na_values='?', header = None)
dataset
# Out:
#      1   2  3   4  5
# 0
# 1   23   3  1  19  3
# 2   15   3  1  17  3
# 1   23   3  2  49  3
# 1    5   2  2  33  3
# 2    7  11  2  55  3
# ..  ..  .. ..  .. ..
# 2    3   2  2  26  1
# 2   10   3  2  12  1
# 1   18   7  2  48  1
# 2   22   1  2  51  1
# 2    2  10  2  27  1
#
# [151 rows x 5 columns]

# %%
# elimina as linhas com dados faltantes
dataset = dataset.dropna(axis=0)
dataset
# Out:
#      1   2  3   4  5
# 0
# 1   23   3  1  19  3
# 2   15   3  1  17  3
# 1   23   3  2  49  3
# 1    5   2  2  33  3
# 2    7  11  2  55  3
# ..  ..  .. ..  .. ..
# 2    3   2  2  26  1
# 2   10   3  2  12  1
# 1   18   7  2  48  1
# 2   22   1  2  51  1
# 2    2  10  2  27  1
#
# [151 rows x 5 columns]

# %%
#Separando as variáveis independentes (conjunto X) e a variável dependente y (que neste caso é a coluna 'status')
X = dataset.loc[:, dataset.columns != 5] 
y = np.array(dataset.loc[:, dataset.columns == 5]).ravel()

# %%
#Define os parametros do metodo de Arvore de Decisao
parameters= {'criterion':['gini'],'max_depth':[4,5,6,7,8,9,10,11,12,15,20,30,40,50,70,90,120,150], 'random_state': [56]}

# %%
# importa o método do sklearn que separa em conjunto de treino e teste
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.26, stratify=y, random_state=56)

# %%
# importa o GridSearchCV
from sklearn.model_selection import GridSearchCV
# importa a arvore de decisão
from sklearn.tree import DecisionTreeClassifier
# instancia o classificador 
clf = DecisionTreeClassifier()
gs_tree = GridSearchCV(clf,parameters, cv = 10, scoring = 'accuracy')
# o grid search treinará todos os modelos conforme a parametrização acima
gs_tree.fit(X,y)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini'],
#                          'max_depth': [4, 5, 6, 7, 8, 9, 10, 11, 12, 15, 20, 30,
#                                        40, 50, 70, 90, 120, 150],
#                          'random_state': [56]},
#              scoring='accuracy')

# %%
# coloca os resultados num Frame para melhor visulização
results = pd.DataFrame(gs_tree.cv_results_)
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.004383      0.000607         0.002560        0.000134
# 1        0.004103      0.000173         0.003553        0.002774
# 2        0.004218      0.000179         0.002951        0.001072
# 3        0.004097      0.000444         0.002883        0.001138
# 4        0.003938      0.000151         0.002385        0.000142
# 5        0.004146      0.000470         0.002513        0.000364
# 6        0.004245      0.000481         0.002555        0.000294
# 7        0.004325      0.000484         0.002638        0.000248
# 8        0.005671      0.002554         0.002541        0.000257
# 9        0.003879      0.000213         0.002526        0.000737
# 10       0.004072      0.000323         0.002342        0.000168
# 11       0.004480      0.002348         0.002270        0.000168
# 12       0.004684      0.002083         0.002241        0.000216
# 13       0.003699      0.000203         0.002255        0.000177
# 14       0.004378      0.001266         0.002792        0.001271
# 15       0.004069      0.000284         0.002472        0.000198
# 16       0.005268      0.003265         0.002602        0.000181
# 17       0.004148      0.000365         0.002414        0.000154
#
#    param_criterion param_max_depth param_random_state  \
# 0             gini               4                 56
# 1             gini               5                 56
# 2             gini               6                 56
# 3             gini               7                 56
# 4             gini               8                 56
# 5             gini               9                 56
# 6             gini              10                 56
# 7             gini              11                 56
# 8             gini              12                 56
# 9             gini              15                 56
# 10            gini              20                 56
# 11            gini              30                 56
# 12            gini              40                 56
# 13            gini              50                 56
# 14            gini              70                 56
# 15            gini              90                 56
# 16            gini             120                 56
# 17            gini             150                 56
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_depth': 4, 'random_...             0.5000
# 1   {'criterion': 'gini', 'max_depth': 5, 'random_...             0.7500
# 2   {'criterion': 'gini', 'max_depth': 6, 'random_...             0.6875
# 3   {'criterion': 'gini', 'max_depth': 7, 'random_...             0.8750
# 4   {'criterion': 'gini', 'max_depth': 8, 'random_...             0.7500
# 5   {'criterion': 'gini', 'max_depth': 9, 'random_...             0.8750
# 6   {'criterion': 'gini', 'max_depth': 10, 'random...             0.8750
# 7   {'criterion': 'gini', 'max_depth': 11, 'random...             0.9375
# 8   {'criterion': 'gini', 'max_depth': 12, 'random...             0.9375
# 9   {'criterion': 'gini', 'max_depth': 15, 'random...             1.0000
# 10  {'criterion': 'gini', 'max_depth': 20, 'random...             1.0000
# 11  {'criterion': 'gini', 'max_depth': 30, 'random...             1.0000
# 12  {'criterion': 'gini', 'max_depth': 40, 'random...             1.0000
# 13  {'criterion': 'gini', 'max_depth': 50, 'random...             1.0000
# 14  {'criterion': 'gini', 'max_depth': 70, 'random...             1.0000
# 15  {'criterion': 'gini', 'max_depth': 90, 'random...             1.0000
# 16  {'criterion': 'gini', 'max_depth': 120, 'rando...             1.0000
# 17  {'criterion': 'gini', 'max_depth': 150, 'rando...             1.0000
#
#     split1_test_score  ...  split3_test_score  split4_test_score  \
# 0            0.466667  ...           0.733333           0.466667
# 1            0.733333  ...           0.733333           0.600000
# 2            0.666667  ...           0.800000           0.666667
# 3            0.666667  ...           0.933333           0.600000
# 4            0.800000  ...           1.000000           0.666667
# 5            0.800000  ...           0.933333           0.733333
# 6            0.933333  ...           0.933333           0.800000
# 7            1.000000  ...           1.000000           0.733333
# 8            1.000000  ...           1.000000           0.733333
# 9            1.000000  ...           1.000000           0.800000
# 10           1.000000  ...           1.000000           0.800000
# 11           1.000000  ...           1.000000           0.800000
# 12           1.000000  ...           1.000000           0.800000
# 13           1.000000  ...           1.000000           0.800000
# 14           1.000000  ...           1.000000           0.800000
# 15           1.000000  ...           1.000000           0.800000
# 16           1.000000  ...           1.000000           0.800000
# 17           1.000000  ...           1.000000           0.800000
#
#     split5_test_score  split6_test_score  split7_test_score  \
# 0            0.400000           0.333333           0.400000
# 1            0.400000           0.333333           0.266667
# 2            0.333333           0.266667           0.333333
# 3            0.400000           0.333333           0.333333
# 4            0.533333           0.333333           0.400000
# 5            0.466667           0.333333           0.400000
# 6            0.466667           0.333333           0.400000
# 7            0.466667           0.400000           0.466667
# 8            0.466667           0.333333           0.533333
# 9            0.466667           0.333333           0.533333
# 10           0.466667           0.333333           0.466667
# 11           0.466667           0.333333           0.466667
# 12           0.466667           0.333333           0.466667
# 13           0.466667           0.333333           0.466667
# 14           0.466667           0.333333           0.466667
# 15           0.466667           0.333333           0.466667
# 16           0.466667           0.333333           0.466667
# 17           0.466667           0.333333           0.466667
#
#     split8_test_score  split9_test_score  mean_test_score  std_test_score  \
# 0            0.333333           0.266667         0.456667        0.139881
# 1            0.400000           0.200000         0.501667        0.195853
# 2            0.400000           0.266667         0.502083        0.191079
# 3            0.400000           0.200000         0.540833        0.232989
# 4            0.266667           0.200000         0.575000        0.254433
# 5            0.266667           0.200000         0.580833        0.260929
# 6            0.266667           0.200000         0.614167        0.291024
# 7            0.266667           0.200000         0.640417        0.298852
# 8            0.333333           0.200000         0.647083        0.294121
# 9            0.266667           0.266667         0.660000        0.301773
# 10           0.266667           0.266667         0.653333        0.305214
# 11           0.266667           0.266667         0.653333        0.305214
# 12           0.266667           0.266667         0.653333        0.305214
# 13           0.266667           0.266667         0.653333        0.305214
# 14           0.266667           0.266667         0.653333        0.305214
# 15           0.266667           0.266667         0.653333        0.305214
# 16           0.266667           0.266667         0.653333        0.305214
# 17           0.266667           0.266667         0.653333        0.305214
#
#     rank_test_score
# 0                18
# 1                17
# 2                16
# 3                15
# 4                14
# 5                13
# 6                12
# 7                11
# 8                10
# 9                 1
# 10                2
# 11                2
# 12                2
# 13                2
# 14                2
# 15                2
# 16                2
# 17                2
#
# [18 rows x 21 columns]

# %%
#criar uma visão para facilitar a visualização dos resultados, e ordenar os resultados conforme os resultados.
view = ['params', 'mean_test_score', 'std_test_score', 'rank_test_score']
results[view].sort_values(by='rank_test_score')
# Out:
#                                                params  mean_test_score  \
# 9   {'criterion': 'gini', 'max_depth': 15, 'random...         0.660000
# 17  {'criterion': 'gini', 'max_depth': 150, 'rando...         0.653333
# 15  {'criterion': 'gini', 'max_depth': 90, 'random...         0.653333
# 14  {'criterion': 'gini', 'max_depth': 70, 'random...         0.653333
# 13  {'criterion': 'gini', 'max_depth': 50, 'random...         0.653333
# 12  {'criterion': 'gini', 'max_depth': 40, 'random...         0.653333
# 11  {'criterion': 'gini', 'max_depth': 30, 'random...         0.653333
# 10  {'criterion': 'gini', 'max_depth': 20, 'random...         0.653333
# 16  {'criterion': 'gini', 'max_depth': 120, 'rando...         0.653333
# 8   {'criterion': 'gini', 'max_depth': 12, 'random...         0.647083
# 7   {'criterion': 'gini', 'max_depth': 11, 'random...         0.640417
# 6   {'criterion': 'gini', 'max_depth': 10, 'random...         0.614167
# 5   {'criterion': 'gini', 'max_depth': 9, 'random_...         0.580833
# 4   {'criterion': 'gini', 'max_depth': 8, 'random_...         0.575000
# 3   {'criterion': 'gini', 'max_depth': 7, 'random_...         0.540833
# 2   {'criterion': 'gini', 'max_depth': 6, 'random_...         0.502083
# 1   {'criterion': 'gini', 'max_depth': 5, 'random_...         0.501667
# 0   {'criterion': 'gini', 'max_depth': 4, 'random_...         0.456667
#
#     std_test_score  rank_test_score
# 9         0.301773                1
# 17        0.305214                2
# 15        0.305214                2
# 14        0.305214                2
# 13        0.305214                2
# 12        0.305214                2
# 11        0.305214                2
# 10        0.305214                2
# 16        0.305214                2
# 8         0.294121               10
# 7         0.298852               11
# 6         0.291024               12
# 5         0.260929               13
# 4         0.254433               14
# 3         0.232989               15
# 2         0.191079               16
# 1         0.195853               17
# 0         0.139881               18

# %% [markdown]
# # Multilayer-Perceptron (redes neurais)

# %%
#Importa as bibliotecas Pandas e Numpy
import pandas as pd
import numpy as np

# %%
# na_values = substitui o valor '?' (dado faltante) para Nan
dataset = pd.read_csv('tae.data', sep=',',  index_col=0, na_values='?', header = None)
dataset
# Out:
#      1   2  3   4  5
# 0
# 1   23   3  1  19  3
# 2   15   3  1  17  3
# 1   23   3  2  49  3
# 1    5   2  2  33  3
# 2    7  11  2  55  3
# ..  ..  .. ..  .. ..
# 2    3   2  2  26  1
# 2   10   3  2  12  1
# 1   18   7  2  48  1
# 2   22   1  2  51  1
# 2    2  10  2  27  1
#
# [151 rows x 5 columns]

# %%
# elimina as linhas com dados faltantes
dataset = dataset.dropna(axis=0)
dataset
# Out:
#      1   2  3   4  5
# 0
# 1   23   3  1  19  3
# 2   15   3  1  17  3
# 1   23   3  2  49  3
# 1    5   2  2  33  3
# 2    7  11  2  55  3
# ..  ..  .. ..  .. ..
# 2    3   2  2  26  1
# 2   10   3  2  12  1
# 1   18   7  2  48  1
# 2   22   1  2  51  1
# 2    2  10  2  27  1
#
# [151 rows x 5 columns]

# %%
#Separando as variáveis independentes (conjunto X) e a variável dependente y (que neste caso é a coluna 'status')
X = dataset.loc[:, dataset.columns != 5] 
y = np.array(dataset.loc[:, dataset.columns == 5]).ravel()

# %%
# importa o algoritmo de classificação Multilayer-Perceptron (redes neurais)
from sklearn.neural_network import MLPClassifier
# importa o GridSearchCV
from sklearn.model_selection import GridSearchCV

# na MLP um parâmetro a ser testado é a quantidade de neurônios na camada escondida, 
# onde utilzamos uma tupla para representar a camada escondida.
# Por exemplo:
# (5) - Cinco neurônios e uma camada escondida
# (8, 5) - Oito neurônios na primeira camada escondida e cinco neurônios na segunda camada escondida.
# Interessante nesse projeto utilizar no máximo duas camadas para verificação 
# Quanto mais camadas e neurônios maior o tempo de processamento do algoritmo
parameters = {'hidden_layer_sizes' : [(5), (8), (15), (5, 3), (8, 5), (10, 5)],
              'max_iter' : [3000], 'random_state' : [56]}

# define o algoritmo de classificação que será usado
mlp = MLPClassifier()
gs_mlp = GridSearchCV(mlp, parameters, cv=10, scoring='accuracy')
# o grid search treinará todos os modelos conforme a parametrização acima
gs_mlp.fit(X, y)
# Out:
# GridSearchCV(cv=10, estimator=MLPClassifier(),
#              param_grid={'hidden_layer_sizes': [5, 8, 15, (5, 3), (8, 5),
#                                                 (10, 5)],
#                          'max_iter': [3000], 'random_state': [56]},
#              scoring='accuracy')

# %%
#criar uma visão para facilitar a visualização dos resultados, e ordenar os resultados conforme os resultados.
view = ['params', 'mean_test_score', 'std_test_score', 'rank_test_score']
results = pd.DataFrame(gs_mlp.cv_results_)
results[view].sort_values(by='rank_test_score')
# Out:
#                                               params  mean_test_score  \
# 4  {'hidden_layer_sizes': (8, 5), 'max_iter': 300...         0.464167
# 0  {'hidden_layer_sizes': 5, 'max_iter': 3000, 'r...         0.463750
# 2  {'hidden_layer_sizes': 15, 'max_iter': 3000, '...         0.455833
# 3  {'hidden_layer_sizes': (5, 3), 'max_iter': 300...         0.404583
# 1  {'hidden_layer_sizes': 8, 'max_iter': 3000, 'r...         0.403750
# 5  {'hidden_layer_sizes': (10, 5), 'max_iter': 30...         0.330417
#
#    std_test_score  rank_test_score
# 4        0.109294                1
# 0        0.084780                2
# 2        0.097472                3
# 3        0.122339                4
# 1        0.112121                5
# 5        0.074303                6

# %% [markdown]
# # Naive Bayes

# %%
#Importa as bibliotecas Pandas e Numpy
import pandas as pd
import numpy as np

# %%
# na_values = substitui o valor '?' (dado faltante) para Nan
dataset = pd.read_csv('tae.data', sep=',',  index_col=0, na_values='?', header = None)
dataset
# Out:
#      1   2  3   4  5
# 0
# 1   23   3  1  19  3
# 2   15   3  1  17  3
# 1   23   3  2  49  3
# 1    5   2  2  33  3
# 2    7  11  2  55  3
# ..  ..  .. ..  .. ..
# 2    3   2  2  26  1
# 2   10   3  2  12  1
# 1   18   7  2  48  1
# 2   22   1  2  51  1
# 2    2  10  2  27  1
#
# [151 rows x 5 columns]

# %%
# elimina as linhas com dados faltantes
dataset = dataset.dropna(axis=0)
dataset
# Out:
#      1   2  3   4  5
# 0
# 1   23   3  1  19  3
# 2   15   3  1  17  3
# 1   23   3  2  49  3
# 1    5   2  2  33  3
# 2    7  11  2  55  3
# ..  ..  .. ..  .. ..
# 2    3   2  2  26  1
# 2   10   3  2  12  1
# 1   18   7  2  48  1
# 2   22   1  2  51  1
# 2    2  10  2  27  1
#
# [151 rows x 5 columns]

# %%
#Separando as variáveis independentes (conjunto X) e a variável dependente y (que neste caso é a coluna 'status')
X = dataset.loc[:, dataset.columns != 5] 
y = np.array(dataset.loc[:, dataset.columns == 5]).ravel()

# %%
#Define os parametros do metodo Naive Bayes
param = {'var_smoothing': np.logspace(0,-9, num=100)}

# %%
# importa o método do sklearn que separa em conjunto de treino e teste
from sklearn.model_selection import train_test_split
# importa o algoritmo Naive Bayes 
from sklearn.naive_bayes import GaussianNB
# importa o GridSearchCV
from sklearn.model_selection import GridSearchCV

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.45, random_state=56)
# instancia o classificador
gnb = GaussianNB()
gs_NB = GridSearchCV(gnb, param, cv = 10, scoring = 'accuracy')
# o grid search treinará todos os modelos conforme a parametrização acima
gs_NB.fit(X,y)
# Out:
# GridSearchCV(cv=10, estimator=GaussianNB(),
#              param_grid={'var_smoothing': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#        4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#        1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#        8.11130831e-02, 6.57933225e-02, 5.33669923e-02, 4.32876128e-02,
#        3.51119173e-02, 2.84803587e-02, 2.3...
#        1.23284674e-07, 1.00000000e-07, 8.11130831e-08, 6.57933225e-08,
#        5.33669923e-08, 4.32876128e-08, 3.51119173e-08, 2.84803587e-08,
#        2.31012970e-08, 1.87381742e-08, 1.51991108e-08, 1.23284674e-08,
#        1.00000000e-08, 8.11130831e-09, 6.57933225e-09, 5.33669923e-09,
#        4.32876128e-09, 3.51119173e-09, 2.84803587e-09, 2.31012970e-09,
#        1.87381742e-09, 1.51991108e-09, 1.23284674e-09, 1.00000000e-09])},
#              scoring='accuracy')

# %%
#criar uma visão para facilitar a visualização dos resultados, e ordenar os resultados conforme os resultados.
view = ['params', 'mean_test_score', 'std_test_score', 'rank_test_score']
results = pd.DataFrame(gs_NB.cv_results_)
results[view].sort_values(by='rank_test_score')
# Out:
#                                       params  mean_test_score  std_test_score  \
# 35  {'var_smoothing': 0.0006579332246575676}         0.515417        0.110806
# 36  {'var_smoothing': 0.0005336699231206307}         0.508750        0.107472
# 33                  {'var_smoothing': 0.001}         0.502083        0.111854
# 34  {'var_smoothing': 0.0008111308307896872}         0.502083        0.111854
# 39  {'var_smoothing': 0.0002848035868435802}         0.495833        0.111009
# ..                                       ...              ...             ...
# 5      {'var_smoothing': 0.3511191734215131}         0.356667        0.078951
# 0                     {'var_smoothing': 1.0}         0.350417        0.120710
# 8      {'var_smoothing': 0.1873817422860384}         0.344167        0.063689
# 7     {'var_smoothing': 0.23101297000831597}         0.344167        0.063689
# 6      {'var_smoothing': 0.2848035868435802}         0.344167        0.063689
#
#     rank_test_score
# 35                1
# 36                2
# 33                3
# 34                3
# 39                5
# ..              ...
# 5                96
# 0                97
# 8                98
# 7                98
# 6                98
#
# [100 rows x 4 columns]

# %% [markdown]
# # K Neighbors

# %%
#Importa as bibliotecas Pandas e Numpy
import pandas as pd
import numpy as np

# %%
# na_values = substitui o valor '?' (dado faltante) para Nan
dataset = pd.read_csv('tae.data', sep=',',  index_col=0, na_values='?', header = None)
dataset
# Out:
#      1   2  3   4  5
# 0
# 1   23   3  1  19  3
# 2   15   3  1  17  3
# 1   23   3  2  49  3
# 1    5   2  2  33  3
# 2    7  11  2  55  3
# ..  ..  .. ..  .. ..
# 2    3   2  2  26  1
# 2   10   3  2  12  1
# 1   18   7  2  48  1
# 2   22   1  2  51  1
# 2    2  10  2  27  1
#
# [151 rows x 5 columns]

# %%
# elimina as linhas com dados faltantes
dataset = dataset.dropna(axis=0)
dataset
# Out:
#      1   2  3   4  5
# 0
# 1   23   3  1  19  3
# 2   15   3  1  17  3
# 1   23   3  2  49  3
# 1    5   2  2  33  3
# 2    7  11  2  55  3
# ..  ..  .. ..  .. ..
# 2    3   2  2  26  1
# 2   10   3  2  12  1
# 1   18   7  2  48  1
# 2   22   1  2  51  1
# 2    2  10  2  27  1
#
# [151 rows x 5 columns]

# %%
#Separando as variáveis independentes (conjunto X) e a variável dependente y (que neste caso é a coluna 'status')
X = dataset.loc[:, dataset.columns != 5] 
y = np.array(dataset.loc[:, dataset.columns == 5]).ravel()

# %%
# importa o algoritmo de classifcaçaõ k-vizinhos
from sklearn.neighbors import KNeighborsClassifier
# importa o GridSearchCV
from sklearn.model_selection import GridSearchCV

# no grid coloca os hiperparâmetros do algoritmo que serão testados (dicionário)
# testará o valor de k com os seguintes valores e o hiperparâmetros weights com os valores 'uniform' e 'distance'
parameters = {'n_neighbors' : [1, 3, 5, 7, 9, 11, 13], 'weights' : ['uniform', 'distance']}

# define o algoritmo de classificação que será usado
knn = KNeighborsClassifier()
''' configura o GridSearch com o algoritmo de classificação = knn (instanciado), os parâmetros testados serão os 
    definidos em parameters, usa cross-validation = 10 e a medida de avaliação é a acurácia.'''  
gs = GridSearchCV(knn, parameters, cv=10, scoring='accuracy')
# o grid search treinará todos os modelos conforme a parametrização acima
gs.fit(X, y)
# Out:
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [1, 3, 5, 7, 9, 11, 13],
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy')

# %%
# coloca os resultados num Frame para melhor visulização
results = pd.DataFrame(gs.cv_results_)
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002650      0.001865         0.002843        0.000782
# 1        0.001848      0.000033         0.002025        0.000088
# 2        0.002255      0.000656         0.002980        0.000913
# 3        0.002243      0.000525         0.002354        0.000415
# 4        0.002150      0.000397         0.002933        0.000720
# 5        0.001804      0.000036         0.002006        0.000101
# 6        0.002010      0.000155         0.002589        0.000257
# 7        0.001861      0.000048         0.002056        0.000071
# 8        0.002628      0.000801         0.003193        0.000746
# 9        0.002253      0.000543         0.002721        0.000624
# 10       0.002555      0.000578         0.003029        0.000528
# 11       0.002029      0.000164         0.002185        0.000146
# 12       0.002234      0.000430         0.002957        0.000513
# 13       0.002329      0.000427         0.002518        0.000492
#
#    param_n_neighbors param_weights  \
# 0                  1       uniform
# 1                  1      distance
# 2                  3       uniform
# 3                  3      distance
# 4                  5       uniform
# 5                  5      distance
# 6                  7       uniform
# 7                  7      distance
# 8                  9       uniform
# 9                  9      distance
# 10                11       uniform
# 11                11      distance
# 12                13       uniform
# 13                13      distance
#
#                                         params  split0_test_score  \
# 0     {'n_neighbors': 1, 'weights': 'uniform'}             0.9375
# 1    {'n_neighbors': 1, 'weights': 'distance'}             0.9375
# 2     {'n_neighbors': 3, 'weights': 'uniform'}             0.5625
# 3    {'n_neighbors': 3, 'weights': 'distance'}             1.0000
# 4     {'n_neighbors': 5, 'weights': 'uniform'}             0.5625
# 5    {'n_neighbors': 5, 'weights': 'distance'}             1.0000
# 6     {'n_neighbors': 7, 'weights': 'uniform'}             0.5000
# 7    {'n_neighbors': 7, 'weights': 'distance'}             1.0000
# 8     {'n_neighbors': 9, 'weights': 'uniform'}             0.4375
# 9    {'n_neighbors': 9, 'weights': 'distance'}             1.0000
# 10   {'n_neighbors': 11, 'weights': 'uniform'}             0.4375
# 11  {'n_neighbors': 11, 'weights': 'distance'}             1.0000
# 12   {'n_neighbors': 13, 'weights': 'uniform'}             0.3125
# 13  {'n_neighbors': 13, 'weights': 'distance'}             1.0000
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            1.000000           0.933333           1.000000
# 1            1.000000           0.933333           1.000000
# 2            0.733333           0.733333           0.466667
# 3            1.000000           0.933333           0.933333
# 4            0.533333           0.600000           0.400000
# 5            1.000000           0.933333           1.000000
# 6            0.466667           0.600000           0.533333
# 7            1.000000           0.933333           1.000000
# 8            0.466667           0.400000           0.533333
# 9            1.000000           0.933333           1.000000
# 10           0.466667           0.533333           0.533333
# 11           1.000000           0.933333           1.000000
# 12           0.600000           0.466667           0.600000
# 13           1.000000           0.933333           1.000000
#
#     split4_test_score  split5_test_score  split6_test_score  \
# 0            0.800000           0.466667           0.400000
# 1            0.800000           0.466667           0.400000
# 2            0.666667           0.333333           0.266667
# 3            0.800000           0.533333           0.400000
# 4            0.666667           0.333333           0.266667
# 5            0.866667           0.533333           0.333333
# 6            0.466667           0.400000           0.400000
# 7            0.800000           0.466667           0.400000
# 8            0.600000           0.266667           0.466667
# 9            0.800000           0.466667           0.400000
# 10           0.466667           0.333333           0.333333
# 11           0.866667           0.466667           0.466667
# 12           0.533333           0.333333           0.333333
# 13           0.866667           0.533333           0.400000
#
#     split7_test_score  split8_test_score  split9_test_score  mean_test_score  \
# 0            0.400000           0.266667           0.266667         0.647083
# 1            0.400000           0.266667           0.266667         0.647083
# 2            0.266667           0.333333           0.266667         0.462917
# 3            0.333333           0.333333           0.200000         0.646667
# 4            0.266667           0.266667           0.200000         0.409583
# 5            0.266667           0.333333           0.266667         0.653333
# 6            0.400000           0.200000           0.333333         0.430000
# 7            0.400000           0.333333           0.200000         0.653333
# 8            0.400000           0.266667           0.466667         0.430417
# 9            0.333333           0.400000           0.266667         0.660000
# 10           0.400000           0.333333           0.400000         0.423750
# 11           0.466667           0.266667           0.333333         0.680000
# 12           0.400000           0.400000           0.333333         0.431250
# 13           0.466667           0.333333           0.266667         0.680000
#
#     std_test_score  rank_test_score
# 0         0.297128                6
# 1         0.297128                6
# 2         0.186231                9
# 3         0.301183                8
# 4         0.158794               14
# 5         0.316649                4
# 6         0.105883               12
# 7         0.305214                4
# 8         0.099409               11
# 9         0.295823                3
# 10        0.073173               13
# 11        0.288752                1
# 12        0.106511               10
# 13        0.290287                1

# %%
#criar uma visão para facilitar a visualização dos resultados, e ordenar os resultados conforme os resultados.
view = ['params', 'mean_test_score', 'std_test_score', 'rank_test_score']
results[view].sort_values(by='rank_test_score')
# Out:
#                                         params  mean_test_score  \
# 11  {'n_neighbors': 11, 'weights': 'distance'}         0.680000
# 13  {'n_neighbors': 13, 'weights': 'distance'}         0.680000
# 9    {'n_neighbors': 9, 'weights': 'distance'}         0.660000
# 5    {'n_neighbors': 5, 'weights': 'distance'}         0.653333
# 7    {'n_neighbors': 7, 'weights': 'distance'}         0.653333
# 0     {'n_neighbors': 1, 'weights': 'uniform'}         0.647083
# 1    {'n_neighbors': 1, 'weights': 'distance'}         0.647083
# 3    {'n_neighbors': 3, 'weights': 'distance'}         0.646667
# 2     {'n_neighbors': 3, 'weights': 'uniform'}         0.462917
# 12   {'n_neighbors': 13, 'weights': 'uniform'}         0.431250
# 8     {'n_neighbors': 9, 'weights': 'uniform'}         0.430417
# 6     {'n_neighbors': 7, 'weights': 'uniform'}         0.430000
# 10   {'n_neighbors': 11, 'weights': 'uniform'}         0.423750
# 4     {'n_neighbors': 5, 'weights': 'uniform'}         0.409583
#
#     std_test_score  rank_test_score
# 11        0.288752                1
# 13        0.290287                1
# 9         0.295823                3
# 5         0.316649                4
# 7         0.305214                4
# 0         0.297128                6
# 1         0.297128                6
# 3         0.301183                8
# 2         0.186231                9
# 12        0.106511               10
# 8         0.099409               11
# 6         0.105883               12
# 10        0.073173               13
# 4         0.158794               14

# %% [markdown]
# # Calculo da Diferenca Absoluta

# %% [markdown]
# Observando os resultados, podemos ver que os metodos MLP e Arvore de Decisao tem as melhores performances, logo temos que calcular a diferenca absoluta para ver qual dos dois e de fato o melhor

# %%
#Calculo do desvio padrao
import math
Dp = math.sqrt(((0.121518)*(0.121518) + (0.059363)*(0.059363))/2)
#Calculo da media
media = (0.813421 - 0.815385)
#calcula da Diferenca Absoluta
DA = media/Dp
print(DA)
#MLP >performance Tree
# Out:
# -0.020537265746999902

# %% [markdown]
# Conclusao: O MLP tem uma melhor performance do que a Arvore de decisao e o restante dos algoritmos
